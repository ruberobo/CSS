# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
import os

# %%
path_1='/Users/ruben/Downloads/Sample/part-'

# %%
path_2='-100d5616-40a1-44f6-97cb-bd2008b34a11-c000.json'

# %%
#pd.read_json('/Users/ruben/Downloads/Sample/part-00729-100d5616-40a1-44f6-97cb-bd2008b34a11-c000.json',lines=True)

# %%
lista_df=[]
for i in range(0,767):
    if len(str(i))==1:
        numero='0000'+str(i)
    elif len(str(i))==2:
        numero='000'+str(i)
    elif len(str(i))==3:
        numero='00'+str(i)
    nombre=path_1+numero+path_2
    df = pd.read_json(nombre, lines=True)
    
    lista_df.append(df)
    #print(i,nombre)

# %%
reviews=pd.concat(lista_df).reset_index(drop=True)

# %%
reviews.dtypes
# Out:
# asin                  object
# overall                int64
# reviewText            object
# dateTime      datetime64[ns]
# verified              object
# year                   int64
# month                  int64
# day                    int64
# dtype: object

# %%
reviews.isnull().sum()
# Out:
# asin            0
# overall         0
# reviewText    929
# dateTime        0
# verified        0
# year            0
# month           0
# day             0
# dtype: int64

# %%
reviews
# Out:
#                asin  overall  \
# 0        B00URJFYEG        4
# 1        0785192395        3
# 2        0785192395        1
# 3        0785192395        5
# 4        B00URJFYEG        4
# ...             ...      ...
# 1402478  0811706222        5
# 1402479  0811713385        5
# 1402480  0811713385        5
# 1402481  0811713385        5
# 1402482  0811713385        5
#
#                                                 reviewText   dateTime  \
# 0        This is one of the more family friendly movies... 2017-01-26
# 1        The art is fine. The plot is ok. Here's the sy... 2018-01-31
# 2        No this is not Thor. This is highly forced lef... 2018-01-28
# 3        Yes, someone new bears the mantle of Thor. And... 2018-01-21
# 4        Very inspiring ; I think this a great movie fo... 2017-01-25
# ...                                                    ...        ...
# 1402478  I thought I'd just glance through the book and... 2012-11-03
# ...

# %%
reviews.to_csv('dataton.csv', sep=',')

# %%
reviews.to_json('dataton.json')

# %%
#pip install google.cloud

# %%
from google.oauth2 import service_account
from google.cloud import bigquery

# %%
import nltk
#nltk.download('punkt')
#nltk.download('wordnet')
#nltk.download('stopwords')
#nltk.download('averaged_perceptron_tagger')
from contractions import fix
from nltk.corpus import stopwords, wordnet
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

# %%
#pip install contractions

# %%
#pip install nltk

# %%
#pip install azure-storage-file-datalake --pre

# %%
sas_token="""
sp=rle&st=2023-07-25T18:12:36Z&se=2023-08-13T02:12:36Z&sv=2022-11-02&sr=
c&sig=l2TCTwPWN8LSM922lR%2Fw78mZWQK2ErEOQDUaCJosIaw%3D


"""

# %%
from azure.storage.filedatalake import DataLakeServiceClient

storage_account_name = "safactoreddatathon"
sas_token = "sp=rle&st=2023-07-25T18:12:36Z&se=2023-08-13T02:12:36Z&sv=2022-11-02&sr=c&sig=l2TCTwPWN8LSM922lR%2Fw78mZWQK2ErEOQDUaCJosIaw%3D"

# Construct the connection string
connection_string = f"DefaultEndpointsProtocol=https;AccountName={storage_account_name};FileEndpoint=https://{storage_account_name}.dfs.core.windows.net;SharedAccessSignature={sas_token}"


from azure.storage.filedatalake import DataLakeFileClient
file = DataLakeFileClient.from_connection_string(connection_string,
                                                 file_system_name="source-files", file_path="amazon_metadata")
with open("/Users/ruben/Downloads/BlockDestination.json", "wb") as my_file:
    # Rest of the code remains the same
    download = file.download_file()
    download.readinto(my_file)

# %%
path_meta='/Users/ruben/Downloads/MetaData'

# %%
for i in os.listdir(path_meta):
    nuevo_path=path_meta+'/'+i

# %%
import pathlib

# %%
dir_meta = [f for f in pathlib.Path('/Users/ruben/Downloads/MetaData').iterdir() ]

# %%
folders_1=[]
for i in dir_meta:
    folder=path_meta+'/'+i.name
    folders_1.append(folder)

# %%
folders_1
# Out:
# ['/Users/ruben/Downloads/MetaData/MetaData 8',
#  '/Users/ruben/Downloads/MetaData/MetaData 6',
#  '/Users/ruben/Downloads/MetaData/MetaData 1',
#  '/Users/ruben/Downloads/MetaData/MetaData 7',
#  '/Users/ruben/Downloads/MetaData/MetaData 9',
#  '/Users/ruben/Downloads/MetaData/.DS_Store',
#  '/Users/ruben/Downloads/MetaData/MetaData 16',
#  '/Users/ruben/Downloads/MetaData/MetaData 11',
#  '/Users/ruben/Downloads/MetaData/MetaData 10',
#  '/Users/ruben/Downloads/MetaData/MetaData 2',
#  '/Users/ruben/Downloads/MetaData/MetaData 5',
#  '/Users/ruben/Downloads/MetaData/MetaData 4',
#  '/Users/ruben/Downloads/MetaData/MetaData 3',
#  '/Users/ruben/Downloads/MetaData/MetaData 12',
#  '/Users/ruben/Downloads/MetaData/MetaData 15',
#  '/Users/ruben/Downloads/MetaData/MetaData 14',
#  '/Users/ruben/Downloads/MetaData/MetaData 13']

# %%
def flatten_list(_2d_list):
    flat_list = []
    # Iterate through the outer list
    for element in _2d_list:
        if type(element) is list:
            # If the element is of type list, iterate through the sublist
            for item in element:
                flat_list.append(item)
        else:
            flat_list.append(element)
    return flat_list

# %%
carpetas=[]
for i in folders_1:
    try:
        carpeta=os.listdir(i)
    except:
        pass
    for j in carpeta:
        subcarpeta=i+'/'+j
        #print(subcarpeta)
        carpetas.append(subcarpeta)

# %%
archivos=[]
for i in carpetas:
    try:
        archivo=i+'/'+os.listdir(i)[0]
        archivos.append(archivo)
    except:
        pass

# %%
archivos
# Out:
# ['/Users/ruben/Downloads/MetaData/MetaData 8/partition_1314/part-00000-tid-3635830397465060407-96b4ebdb-ae52-40f2-8cb7-ecef91c001ce-2627-1-c000.json',
#  '/Users/ruben/Downloads/MetaData/MetaData 8/partition_1313/part-00000-tid-5656929803695353225-cd0a6e84-1767-459f-9a4c-079acb3b71e8-2625-1-c000.json',
#  '/Users/ruben/Downloads/MetaData/MetaData 8/partition_1312/part-00000-tid-497618680527344837-181ddf1b-86ec-46a3-98b5-cf7cd6a838ff-2623-1-c000.json',
#  '/Users/ruben/Downloads/MetaData/MetaData 8/partition_141/part-00000-tid-905822855752436906-3116cc6c-9d6b-45a0-a42b-732498235eab-281-1-c000.json',
#  '/Users/ruben/Downloads/MetaData/MetaData 8/partition_1415/part-00000-tid-5992244173450932549-1a3e84dd-118e-4808-a888-11ba1cf83fc0-2829-1-c000.json',
#  '/Users/ruben/Downloads/MetaData/MetaData 8/partition_1364/part-00000-tid-8055586000942906332-7ed0597e-48e8-42fb-9813-2103b116be6b-2727-1-c000.json',
# ...

# %%
archivos[0]
# Out:
# '/Users/ruben/Downloads/MetaData/MetaData 8/partition_1314/part-00000-tid-3635830397465060407-96b4ebdb-ae52-40f2-8cb7-ecef91c001ce-2627-1-c000.json'

# %%
lista_df_2=[]
for i in archivos:
    df = pd.read_json(i, lines=True)
    lista_df_2.append(df)
    print('ok')
# Out:
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ...

# %%
metadata=pd.concat(lista_df_2).reset_index(drop=True)

# %%
metadata
# Out:
#              also_buy                                          also_view  \
# 0                  []                                                 []
# 1                  []                                       [B000C59WBG]
# 2                  []                                                 []
# 3                  []                                                 []
# 4                  []                                                 []
# ...               ...                                                ...
# 6626113  [B017AQY1Q0]  [B017AQY1Q0, B01N4UUM8V, B01CMXGSL2, B01M31CYL...
# 6626114            []                                                 []
# 6626115            []                                                 []
# 6626116            []                                                 []
# 6626117  [B078MWY4SX]  [B00LXMSFMO, B01MU7T4DB, B01IKGG2DE, B00JQNATR...
#
#                asin      brand  \
# 0        B006N96IX0    ACDelco
# ...

# %%
#metadata.to_csv('metadata.csv', sep=',')

# %%
metadata_sample=metadata.sample(frac=0.22)

# %%
metadata_sample
# Out:
#                                                   also_buy  \
# 2915342                                                 []
# 2343106                                                 []
# 3309372                                                 []
# 3964651  [1632865793, 0691156948, 0544558146, 194364501...
# 3720470                                                 []
# ...                                                    ...
# 6062593                                                 []
# 724248   [0520025911, 1935879944, 1612124380, 094236708...
# 3483616                                                 []
# 4212726   [0316433799, 0060958707, 161519102X, 0884961621]
# 5911007                                                 []
#
#                                                  also_view        asin  \
# 2915342                                                 []  B01C7FKXSO
# 2343106               [B01FMLP38K, B004W8RO2S, B00GD3GKUC]  B006VM5J7U
# ...

# %%
metadata_sample.to_csv('sample_metadata.csv', sep=',')
