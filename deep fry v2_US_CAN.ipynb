# %%
#importo categorias de sales force
import json
import pandas as pd
import numpy as np
import json

# UNCOMMENT IF YOU DO NOT HAVE SIMPLE_SALESFORCE INSTALLED
#!pip install simple_salesforce 
from simple_salesforce import Salesforce, SalesforceLogin, SFType


path = "/home/ruben.lopez/creds_sales_force.json"

loginInfo = json.load(open(path))
session_id, instance = SalesforceLogin(username= loginInfo['username'],
                                                 password=loginInfo['password'],
                                                 security_token=loginInfo['security_token'],
                                                 domain='login')

sf = Salesforce(instance=instance, session_id=session_id)

# %%
import warnings

warnings.simplefilter("ignore")

from IPython.display import HTML, display

display(
    HTML(
        data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 95%; }
    div#maintoolbar-container { width: 95%; }
</style>
"""
    )
)


import json
import os

# Importing libraries
import pandas as pd
from ds.utilities.io import ds_trino

pd.options.display.max_columns = None
pd.options.display.max_rows = 50
pd.options.mode.chained_assignment = None


conn = ds_trino.create_trino_connection()
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 95%; }
#     div#maintoolbar-container { width: 95%; }
# </style>

# %%
import re

# %%
import datetime

# %%
# ### leads latam
query_leads = """

SELECT Id, CreatedBy.Name, Created_by_Title__c, Created_By_Role__c, Created_by_Manager__c, Name, Kitchen_Country__c, Kitchen_City__c, Company, Email, Create_Date_Time__c,CreatedDate, Lead_Owner_Country__c, Lead_Owner_Role__c, owner.Name, Lead_Unqualified_Date__c,
SalesLoft1__Most_Recent_Cadence_Name__c, LeadSource,
Status, Qualified_Date__c, Time_to_covert_to_Opp__c, Lead_Closed_Reason__c, 
Lead_Closed_Explanation__c, Campaign__c, Campaign_Detail__c, Refreshed_Lead__c, Refreshed_Date__c, 
Days_Since_Last_Activity__c, Days_Since_Last_Call__c, RecordType.Name, Assigned_Date__c, 
First_Call_Date_Time__c, Lead_Processed__c, of_Activities_Till_Convert__c,  
of_Calls_till_convert__c
from Lead
where RecordType.Name in ('Virtual', 'CloudRetail','virtual;cloudretail') and 
Lead_Owner_Region__c in('US/CAN')


"""


print('Getting User Data...')

# Query users to dataframe
leads = pd.DataFrame(sf.query_all(query_leads)['records'])
print('Users Pulled')

leads
# Out:
# Getting User Data...
# Users Pulled
#                                               attributes                  Id  \
# 0      {'type': 'Lead', 'url': '/services/data/v42.0/...  00Q5G00000Sfy6lUAB
# 1      {'type': 'Lead', 'url': '/services/data/v42.0/...  00Q5G00000SgdK8UAJ
# 2      {'type': 'Lead', 'url': '/services/data/v42.0/...  00Q5G00000SgdjxUAB
# 3      {'type': 'Lead', 'url': '/services/data/v42.0/...  00Q5G00000SgkGqUAJ
# 4      {'type': 'Lead', 'url': '/services/data/v42.0/...  00Q5G00000SgkP9UAJ
# ...                                                  ...                 ...
# 66015  {'type': 'Lead', 'url': '/services/data/v42.0/...  00Qf400000S8SEgEAN
# 66016  {'type': 'Lead', 'url': '/services/data/v42.0/...  00Qf400000S9qtSEAR
# 66017  {'type': 'Lead', 'url': '/services/data/v42.0/...  00Qf400000SACylEAH
# 66018  {'type': 'Lead', 'url': '/services/data/v42.0/...  00Qf400000SApFgEAL
# 66019  {'type': 'Lead', 'url': '/services/data/v42.0/...  00Qf400000Sf6XUEAZ
#
#                                                CreatedBy Created_by_Title__c  \
# 0      {'attributes': {'type': 'User', 'url': '/servi...               LATAM
# 1      {'attributes': {'type': 'User', 'url': '/servi...                None
# 2      {'attributes': {'type': 'User', 'url': '/servi...   Marketing Manager
# 3      {'attributes': {'type': 'User', 'url': '/servi...   Marketing Manager
# 4      {'attributes': {'type': 'User', 'url': '/servi...   Marketing Manager
# ...                                                  ...                 ...
# 66015  {'attributes': {'type': 'User', 'url': '/servi...                None
# 66016  {'attributes': {'type': 'User', 'url': '/servi...                None
# 66017  {'attributes': {'type': 'User', 'url': '/servi...                None
# 66018  {'attributes': {'type': 'User', 'url': '/servi...                None
# 66019  {'attributes': {'type': 'User', 'url': '/servi...               LATAM
#
#          Created_By_Role__c Created_by_Manager__c  \
# 0          Sales Operations         Barbara Garza
# 1      US Account Executive            Jack Green
# 2               Super Admin       Jacques de Haes
# 3               Super Admin       Jacques de Haes
# 4               Super Admin       Jacques de Haes
# ...                     ...                   ...
# 66015           Super Admin                  None
# 66016           Super Admin                  None
# 66017           Super Admin                  None
# 66018           Super Admin         Sathya Murthy
# 66019      Sales Operations         Barbara Garza
#
#                                   Name Kitchen_Country__c Kitchen_City__c  \
# 0               Carmen Sanguino Gamboa             Mexico     Mexico City
# 1                        Marla Topliff               None         Chicago
# 2                         Modupe jacob      United States         Atlanta
# 3           FIrst Name Citron Catering      United States     Los Angeles
# 4      first name Fire & Wine Catering      United States     Los Angeles
# ...                                ...                ...             ...
# 66015                    Alicia Zuñiga             Mexico     Mexico City
# 66016                 Eduardo Bautista             Mexico     Mexico City
# 66017                Sebastian Mompala             Mexico     Mexico City
# 66018                   Shera Fournier      United States     Los Angeles
# 66019                   Nohemi Enguilo             Mexico     Mexico City
#
#                     Company                           Email  \
# 0              Littleponkis    carmensanguino1315@gmail.com
# 1              Suzy's Swirl            marla@suzysswirl.com
# 2             nifty fingers          modupe.jacob@gmail.com
# 3           Citron Catering  contactus@citroncateringaz.com
# 4      Fire & Wine Catering   fireandwinecatering@gmail.com
# ...                     ...                             ...
# 66015      El Queso Gourmet             lazwittig@gmail.com
# 66016            House cake            lalo.23hc@icloud.com
# 66017      Café one chingon              smompala@gmail.com
# 66018                 Veron          sfournier@theveron.com
# 66019            Pastelitos       nohemi_enguilo@icloud.com
#
#                 Create_Date_Time__c                   CreatedDate  \
# 0      2020-11-08T22:02:52.000+0000  2020-11-08T22:02:52.000+0000
# 1      2020-11-13T01:24:58.000+0000  2020-11-13T01:24:58.000+0000
# 2      2020-11-13T04:04:22.000+0000  2020-11-13T04:04:22.000+0000
# 3      2020-11-13T17:44:58.000+0000  2020-11-13T17:44:58.000+0000
# 4      2020-11-13T17:45:13.000+0000  2020-11-13T17:45:13.000+0000
# ...                             ...                           ...
# 66015  2020-10-19T03:46:51.000+0000  2020-10-19T03:46:51.000+0000
# 66016  2020-10-22T21:52:15.000+0000  2020-10-22T21:52:15.000+0000
# 66017  2020-10-24T21:29:40.000+0000  2020-10-24T21:29:40.000+0000
# 66018  2020-10-28T06:37:00.000+0000  2020-10-28T06:37:00.000+0000
# 66019  2020-11-02T15:28:07.000+0000  2020-11-02T15:28:07.000+0000
#
#           Lead_Owner_Country__c                   Lead_Owner_Role__c  \
# 0      United States of America                  US Customer Success
# 1      United States of America  Sales Development Representative CR
# 2      United States of America                 US Account Executive
# 3                           USA                 US Account Executive
# 4                           USA                 US Account Executive
# ...                         ...                                  ...
# 66015  United States of America                     US Sales Manager
# 66016  United States of America                     US Sales Manager
# 66017  United States of America                  US Customer Success
# 66018  United States of America          CR - Account Executive (AE)
# 66019  United States of America                     US Sales Manager
#
#                                                    Owner  \
# 0      {'attributes': {'type': 'Name', 'url': '/servi...
# 1      {'attributes': {'type': 'Name', 'url': '/servi...
# 2      {'attributes': {'type': 'Name', 'url': '/servi...
# 3      {'attributes': {'type': 'Name', 'url': '/servi...
# 4      {'attributes': {'type': 'Name', 'url': '/servi...
# ...                                                  ...
# 66015  {'attributes': {'type': 'Name', 'url': '/servi...
# 66016  {'attributes': {'type': 'Name', 'url': '/servi...
# 66017  {'attributes': {'type': 'Name', 'url': '/servi...
# 66018  {'attributes': {'type': 'Name', 'url': '/servi...
# 66019  {'attributes': {'type': 'Name', 'url': '/servi...
#
#       Lead_Unqualified_Date__c SalesLoft1__Most_Recent_Cadence_Name__c  \
# 0                         None       Inbound Virtual Kitchens - Mexico
# 1                         None                         Lead/Qualifying
# 2                         None                           after inbound
# 3                         None                                    None
# 4                   2022-07-29        LA Katy Perry's Cadence 🎆 - mike
# ...                        ...                                     ...
# 66015                     None       Inbound Virtual Kitchens - Mexico
# 66016                     None       Inbound Virtual Kitchens - Mexico
# 66017                     None       Inbound Virtual Kitchens - Mexico
# 66018                     None             SDR - Inbound Cadence (v.2)
# 66019               2022-05-17            SDR MX - Inbound CloudRetail
#
#                           LeadSource                  Status  \
# 0                  Inbound: Facebook               Qualified
# 1      Outbound: Targeted email/call                     New
# 2                  Inbound: Facebook  Closed - Not Converted
# 3                Data Science Scrape                     New
# 4                Data Science Scrape  Closed - Not Converted
# ...                              ...                     ...
# 66015               Inbound: Website               Qualified
# 66016               Inbound: Website               Qualified
# 66017                 Inbound: Other          Not Interested
# 66018         Inbound: Google Search  Closed - Not Converted
# 66019              Inbound: Facebook  Closed - Not Converted
#
#       Qualified_Date__c  Time_to_covert_to_Opp__c     Lead_Closed_Reason__c  \
# 0                  None                       1.0                      None
# 1                  None                       NaN                      None
# 2                  None                       NaN       Disconnected Number
# 3                  None                       NaN                      None
# 4                  None                       NaN             Did Not Reach
# ...                 ...                       ...                       ...
# 66015              None                       3.0                      None
# 66016              None                       0.0                      None
# 66017              None                       NaN                      None
# 66018              None                       NaN  Not Interested - Pricing
# 66019              None                       NaN             Did Not Reach
#
#       Lead_Closed_Explanation__c         Campaign__c Campaign_Detail__c  \
# 0                           None  7015G000001hUN8QAM               None
# 1                           None                None               None
# 2                           None                None               None
# 3                           None                None               None
# 4                           None                None               None
# ...                          ...                 ...                ...
# 66015                       None  7015G000001hUN8QAM               None
# 66016                       None  7015G000001hUN8QAM               None
# 66017                       None  7015G000000kdneQAA               None
# 66018                       None                None               None
# 66019                       None                None               None
#
#        Refreshed_Lead__c Refreshed_Date__c  Days_Since_Last_Activity__c  \
# 0                  False              None                          NaN
# 1                  False              None                        131.0
# 2                  False              None                        542.0
# 3                  False              None                          NaN
# 4                  False              None                         61.0
# ...                  ...               ...                          ...
# 66015              False              None                          NaN
# 66016              False              None                          NaN
# 66017               True              None                        980.0
# 66018              False              None                        496.0
# 66019              False              None                        427.0
#
#        Days_Since_Last_Call__c  \
# 0                        966.0
# 1                        136.0
# 2                        542.0
# 3                        962.0
# 4                        962.0
# ...                        ...
# 66015                    988.0
# 66016                    984.0
# 66017                    982.0
# 66018                    831.0
# 66019                    973.0
#
#                                               RecordType Assigned_Date__c  \
# 0      {'attributes': {'type': 'RecordType', 'url': '...             None
# 1      {'attributes': {'type': 'RecordType', 'url': '...             None
# 2      {'attributes': {'type': 'RecordType', 'url': '...       2022-02-22
# 3      {'attributes': {'type': 'RecordType', 'url': '...             None
# 4      {'attributes': {'type': 'RecordType', 'url': '...             None
# ...                                                  ...              ...
# 66015  {'attributes': {'type': 'RecordType', 'url': '...             None
# 66016  {'attributes': {'type': 'RecordType', 'url': '...             None
# 66017  {'attributes': {'type': 'RecordType', 'url': '...             None
# 66018  {'attributes': {'type': 'RecordType', 'url': '...             None
# 66019  {'attributes': {'type': 'RecordType', 'url': '...             None
#
#             First_Call_Date_Time__c  Lead_Processed__c  \
# 0      2020-11-09T17:57:03.000+0000               True
# 1      2023-02-13T18:45:29.000+0000              False
# 2      2020-12-03T15:28:29.000+0000               True
# 3                              None              False
# 4                              None               True
# ...                             ...                ...
# 66015                          None               True
# 66016                          None               True
# 66017                          None               True
# 66018  2020-10-30T00:03:27.000+0000               True
# 66019                          None               True
#
#        of_Activities_Till_Convert__c  of_Calls_till_convert__c
# 0                                2.0                       1.0
# 1                                6.0                       2.0
# 2                                1.0                       1.0
# 3                                0.0                       0.0
# 4                               14.0                       0.0
# ...                              ...                       ...
# 66015                            0.0                       NaN
# 66016                            1.0                       NaN
# 66017                            3.0                       0.0
# 66018                            1.0                       0.0
# 66019                            1.0                       0.0
#
# [66020 rows x 36 columns]

# %%
#leads['CreatedBy'][50]

# %%
lista_created_by=[]

for i in range(len(leads)):
    try:
        valor=leads['CreatedBy'][i]['Name']
    except:
        valor='no name'
        
    lista_created_by.append(valor)

# %%
leads['CreatedBy_name']=lista_created_by

# %%
leads['Owner'][20]
# Out:
# OrderedDict([('attributes',
#               OrderedDict([('type', 'Name'),
#                            ('url',
#                             '/services/data/v42.0/sobjects/User/005f4000005tk83AAA')])),
#              ('Name', 'Gabriela Osorio')])

# %%
lista_owner_name=[]

for i in range(len(leads)):
    try:
        valor=leads['Owner'][i]['Name']
    except:
        valor='no owner'
        
    lista_owner_name.append(valor)

# %%
leads['owner_name']=lista_owner_name

# %%
leads['RecordType'][100]
# Out:
# OrderedDict([('attributes',
#               OrderedDict([('type', 'RecordType'),
#                            ('url',
#                             '/services/data/v42.0/sobjects/RecordType/0125G000000fa8MQAQ')])),
#              ('Name', 'CloudRetail')])

# %%
lista_recordtype_name=[]

for i in range(len(leads)):
    try:
        valor=leads['RecordType'][i]['Name']
    except:
        valor='no Record_type'
        
    lista_recordtype_name.append(valor)

# %%
leads['record_type_name']=lista_recordtype_name

# %%
leads
# Out:
#                                               attributes                  Id  \
# 0      {'type': 'Lead', 'url': '/services/data/v42.0/...  00Q5G00000Sfy6lUAB
# 1      {'type': 'Lead', 'url': '/services/data/v42.0/...  00Q5G00000SgdK8UAJ
# 2      {'type': 'Lead', 'url': '/services/data/v42.0/...  00Q5G00000SgdjxUAB
# 3      {'type': 'Lead', 'url': '/services/data/v42.0/...  00Q5G00000SgkGqUAJ
# 4      {'type': 'Lead', 'url': '/services/data/v42.0/...  00Q5G00000SgkP9UAJ
# ...                                                  ...                 ...
# 66015  {'type': 'Lead', 'url': '/services/data/v42.0/...  00Qf400000S8SEgEAN
# 66016  {'type': 'Lead', 'url': '/services/data/v42.0/...  00Qf400000S9qtSEAR
# 66017  {'type': 'Lead', 'url': '/services/data/v42.0/...  00Qf400000SACylEAH
# 66018  {'type': 'Lead', 'url': '/services/data/v42.0/...  00Qf400000SApFgEAL
# 66019  {'type': 'Lead', 'url': '/services/data/v42.0/...  00Qf400000Sf6XUEAZ
#
#                                                CreatedBy Created_by_Title__c  \
# 0      {'attributes': {'type': 'User', 'url': '/servi...               LATAM
# 1      {'attributes': {'type': 'User', 'url': '/servi...                None
# 2      {'attributes': {'type': 'User', 'url': '/servi...   Marketing Manager
# 3      {'attributes': {'type': 'User', 'url': '/servi...   Marketing Manager
# 4      {'attributes': {'type': 'User', 'url': '/servi...   Marketing Manager
# ...                                                  ...                 ...
# 66015  {'attributes': {'type': 'User', 'url': '/servi...                None
# 66016  {'attributes': {'type': 'User', 'url': '/servi...                None
# 66017  {'attributes': {'type': 'User', 'url': '/servi...                None
# 66018  {'attributes': {'type': 'User', 'url': '/servi...                None
# 66019  {'attributes': {'type': 'User', 'url': '/servi...               LATAM
#
#          Created_By_Role__c Created_by_Manager__c  \
# 0          Sales Operations         Barbara Garza
# 1      US Account Executive            Jack Green
# 2               Super Admin       Jacques de Haes
# 3               Super Admin       Jacques de Haes
# 4               Super Admin       Jacques de Haes
# ...                     ...                   ...
# 66015           Super Admin                  None
# 66016           Super Admin                  None
# 66017           Super Admin                  None
# 66018           Super Admin         Sathya Murthy
# 66019      Sales Operations         Barbara Garza
#
#                                   Name Kitchen_Country__c Kitchen_City__c  \
# 0               Carmen Sanguino Gamboa             Mexico     Mexico City
# 1                        Marla Topliff               None         Chicago
# 2                         Modupe jacob      United States         Atlanta
# 3           FIrst Name Citron Catering      United States     Los Angeles
# 4      first name Fire & Wine Catering      United States     Los Angeles
# ...                                ...                ...             ...
# 66015                    Alicia Zuñiga             Mexico     Mexico City
# 66016                 Eduardo Bautista             Mexico     Mexico City
# 66017                Sebastian Mompala             Mexico     Mexico City
# 66018                   Shera Fournier      United States     Los Angeles
# 66019                   Nohemi Enguilo             Mexico     Mexico City
#
#                     Company                           Email  \
# 0              Littleponkis    carmensanguino1315@gmail.com
# 1              Suzy's Swirl            marla@suzysswirl.com
# 2             nifty fingers          modupe.jacob@gmail.com
# 3           Citron Catering  contactus@citroncateringaz.com
# 4      Fire & Wine Catering   fireandwinecatering@gmail.com
# ...                     ...                             ...
# 66015      El Queso Gourmet             lazwittig@gmail.com
# 66016            House cake            lalo.23hc@icloud.com
# 66017      Café one chingon              smompala@gmail.com
# 66018                 Veron          sfournier@theveron.com
# 66019            Pastelitos       nohemi_enguilo@icloud.com
#
#                 Create_Date_Time__c                   CreatedDate  \
# 0      2020-11-08T22:02:52.000+0000  2020-11-08T22:02:52.000+0000
# 1      2020-11-13T01:24:58.000+0000  2020-11-13T01:24:58.000+0000
# 2      2020-11-13T04:04:22.000+0000  2020-11-13T04:04:22.000+0000
# 3      2020-11-13T17:44:58.000+0000  2020-11-13T17:44:58.000+0000
# 4      2020-11-13T17:45:13.000+0000  2020-11-13T17:45:13.000+0000
# ...                             ...                           ...
# 66015  2020-10-19T03:46:51.000+0000  2020-10-19T03:46:51.000+0000
# 66016  2020-10-22T21:52:15.000+0000  2020-10-22T21:52:15.000+0000
# 66017  2020-10-24T21:29:40.000+0000  2020-10-24T21:29:40.000+0000
# 66018  2020-10-28T06:37:00.000+0000  2020-10-28T06:37:00.000+0000
# 66019  2020-11-02T15:28:07.000+0000  2020-11-02T15:28:07.000+0000
#
#           Lead_Owner_Country__c                   Lead_Owner_Role__c  \
# 0      United States of America                  US Customer Success
# 1      United States of America  Sales Development Representative CR
# 2      United States of America                 US Account Executive
# 3                           USA                 US Account Executive
# 4                           USA                 US Account Executive
# ...                         ...                                  ...
# 66015  United States of America                     US Sales Manager
# 66016  United States of America                     US Sales Manager
# 66017  United States of America                  US Customer Success
# 66018  United States of America          CR - Account Executive (AE)
# 66019  United States of America                     US Sales Manager
#
#                                                    Owner  \
# 0      {'attributes': {'type': 'Name', 'url': '/servi...
# 1      {'attributes': {'type': 'Name', 'url': '/servi...
# 2      {'attributes': {'type': 'Name', 'url': '/servi...
# 3      {'attributes': {'type': 'Name', 'url': '/servi...
# 4      {'attributes': {'type': 'Name', 'url': '/servi...
# ...                                                  ...
# 66015  {'attributes': {'type': 'Name', 'url': '/servi...
# 66016  {'attributes': {'type': 'Name', 'url': '/servi...
# 66017  {'attributes': {'type': 'Name', 'url': '/servi...
# 66018  {'attributes': {'type': 'Name', 'url': '/servi...
# 66019  {'attributes': {'type': 'Name', 'url': '/servi...
#
#       Lead_Unqualified_Date__c SalesLoft1__Most_Recent_Cadence_Name__c  \
# 0                         None       Inbound Virtual Kitchens - Mexico
# 1                         None                         Lead/Qualifying
# 2                         None                           after inbound
# 3                         None                                    None
# 4                   2022-07-29        LA Katy Perry's Cadence 🎆 - mike
# ...                        ...                                     ...
# 66015                     None       Inbound Virtual Kitchens - Mexico
# 66016                     None       Inbound Virtual Kitchens - Mexico
# 66017                     None       Inbound Virtual Kitchens - Mexico
# 66018                     None             SDR - Inbound Cadence (v.2)
# 66019               2022-05-17            SDR MX - Inbound CloudRetail
#
#                           LeadSource                  Status  \
# 0                  Inbound: Facebook               Qualified
# 1      Outbound: Targeted email/call                     New
# 2                  Inbound: Facebook  Closed - Not Converted
# 3                Data Science Scrape                     New
# 4                Data Science Scrape  Closed - Not Converted
# ...                              ...                     ...
# 66015               Inbound: Website               Qualified
# 66016               Inbound: Website               Qualified
# 66017                 Inbound: Other          Not Interested
# 66018         Inbound: Google Search  Closed - Not Converted
# 66019              Inbound: Facebook  Closed - Not Converted
#
#       Qualified_Date__c  Time_to_covert_to_Opp__c     Lead_Closed_Reason__c  \
# 0                  None                       1.0                      None
# 1                  None                       NaN                      None
# 2                  None                       NaN       Disconnected Number
# 3                  None                       NaN                      None
# 4                  None                       NaN             Did Not Reach
# ...                 ...                       ...                       ...
# 66015              None                       3.0                      None
# 66016              None                       0.0                      None
# 66017              None                       NaN                      None
# 66018              None                       NaN  Not Interested - Pricing
# 66019              None                       NaN             Did Not Reach
#
#       Lead_Closed_Explanation__c         Campaign__c Campaign_Detail__c  \
# 0                           None  7015G000001hUN8QAM               None
# 1                           None                None               None
# 2                           None                None               None
# 3                           None                None               None
# 4                           None                None               None
# ...                          ...                 ...                ...
# 66015                       None  7015G000001hUN8QAM               None
# 66016                       None  7015G000001hUN8QAM               None
# 66017                       None  7015G000000kdneQAA               None
# 66018                       None                None               None
# 66019                       None                None               None
#
#        Refreshed_Lead__c Refreshed_Date__c  Days_Since_Last_Activity__c  \
# 0                  False              None                          NaN
# 1                  False              None                        131.0
# 2                  False              None                        542.0
# 3                  False              None                          NaN
# 4                  False              None                         61.0
# ...                  ...               ...                          ...
# 66015              False              None                          NaN
# 66016              False              None                          NaN
# 66017               True              None                        980.0
# 66018              False              None                        496.0
# 66019              False              None                        427.0
#
#        Days_Since_Last_Call__c  \
# 0                        966.0
# 1                        136.0
# 2                        542.0
# 3                        962.0
# 4                        962.0
# ...                        ...
# 66015                    988.0
# 66016                    984.0
# 66017                    982.0
# 66018                    831.0
# 66019                    973.0
#
#                                               RecordType Assigned_Date__c  \
# 0      {'attributes': {'type': 'RecordType', 'url': '...             None
# 1      {'attributes': {'type': 'RecordType', 'url': '...             None
# 2      {'attributes': {'type': 'RecordType', 'url': '...       2022-02-22
# 3      {'attributes': {'type': 'RecordType', 'url': '...             None
# 4      {'attributes': {'type': 'RecordType', 'url': '...             None
# ...                                                  ...              ...
# 66015  {'attributes': {'type': 'RecordType', 'url': '...             None
# 66016  {'attributes': {'type': 'RecordType', 'url': '...             None
# 66017  {'attributes': {'type': 'RecordType', 'url': '...             None
# 66018  {'attributes': {'type': 'RecordType', 'url': '...             None
# 66019  {'attributes': {'type': 'RecordType', 'url': '...             None
#
#             First_Call_Date_Time__c  Lead_Processed__c  \
# 0      2020-11-09T17:57:03.000+0000               True
# 1      2023-02-13T18:45:29.000+0000              False
# 2      2020-12-03T15:28:29.000+0000               True
# 3                              None              False
# 4                              None               True
# ...                             ...                ...
# 66015                          None               True
# 66016                          None               True
# 66017                          None               True
# 66018  2020-10-30T00:03:27.000+0000               True
# 66019                          None               True
#
#        of_Activities_Till_Convert__c  of_Calls_till_convert__c  \
# 0                                2.0                       1.0
# 1                                6.0                       2.0
# 2                                1.0                       1.0
# 3                                0.0                       0.0
# 4                               14.0                       0.0
# ...                              ...                       ...
# 66015                            0.0                       NaN
# 66016                            1.0                       NaN
# 66017                            3.0                       0.0
# 66018                            1.0                       0.0
# 66019                            1.0                       0.0
#
#              CreatedBy_name         owner_name record_type_name
# 0           Esteban Cardona    Gabriela Osorio      CloudRetail
# 1            Connor McCarty       Chris Scarpa      CloudRetail
# 2              Siyaa Munjal      Amanda Scheer      CloudRetail
# 3              Siyaa Munjal  Matthew Kulpinski      CloudRetail
# 4              Siyaa Munjal  Matthew Kulpinski      CloudRetail
# ...                     ...                ...              ...
# 66015  Christopher Schwartz       Ariana Winer      CloudRetail
# 66016  Christopher Schwartz       Ariana Winer      CloudRetail
# 66017  Christopher Schwartz    Gabriela Osorio      CloudRetail
# 66018      Mitchell Mendoza      Zakary Garcia      CloudRetail
# 66019       Esteban Cardona       Ariana Winer      CloudRetail
#
# [66020 rows x 39 columns]

# %%
leads.columns
# Out:
# Index(['attributes', 'Id', 'CreatedBy', 'Created_by_Title__c',
#        'Created_By_Role__c', 'Created_by_Manager__c', 'Name',
#        'Kitchen_Country__c', 'Kitchen_City__c', 'Company', 'Email',
#        'Create_Date_Time__c', 'CreatedDate', 'Lead_Owner_Country__c',
#        'Lead_Owner_Role__c', 'Owner', 'Lead_Unqualified_Date__c',
#        'SalesLoft1__Most_Recent_Cadence_Name__c', 'LeadSource', 'Status',
#        'Qualified_Date__c', 'Time_to_covert_to_Opp__c',
#        'Lead_Closed_Reason__c', 'Lead_Closed_Explanation__c', 'Campaign__c',
#        'Campaign_Detail__c', 'Refreshed_Lead__c', 'Refreshed_Date__c',
#        'Days_Since_Last_Activity__c', 'Days_Since_Last_Call__c', 'RecordType',
#        'Assigned_Date__c', 'First_Call_Date_Time__c', 'Lead_Processed__c',
#        'of_Activities_Till_Convert__c', 'of_Calls_till_convert__c',
#        'CreatedBy_name', 'owner_name', 'record_type_name'],
#       dtype='object')

# %%
leads_exp=leads[['CreatedBy_name', 'owner_name', 'record_type_name','Id',  'Created_by_Title__c',
       'Created_By_Role__c', 'Created_by_Manager__c', 'Name',
       'Kitchen_Country__c', 'Kitchen_City__c', 'Company', 'Email',
       'Create_Date_Time__c', 'CreatedDate', 'Lead_Owner_Country__c',
       'Lead_Owner_Role__c','Lead_Unqualified_Date__c', 'Qualified_Date__c',
       'SalesLoft1__Most_Recent_Cadence_Name__c', 'LeadSource',
       'Status', 'Time_to_covert_to_Opp__c',
       'Lead_Closed_Reason__c', 'Lead_Closed_Explanation__c', 'Campaign__c',
       'Campaign_Detail__c', 'Refreshed_Lead__c', 'Refreshed_Date__c',
       'Days_Since_Last_Activity__c', 'Days_Since_Last_Call__c',
               'Assigned_Date__c', 'First_Call_Date_Time__c', 'Lead_Processed__c',
                 'of_Activities_Till_Convert__c', 'of_Calls_till_convert__c'
 ]]

# %%
leads_exp_2=leads_exp.rename(columns={'Id':'lead_ID'})

# %%
leads_exp_2
# Out:
#              CreatedBy_name         owner_name record_type_name  \
# 0           Esteban Cardona    Gabriela Osorio      CloudRetail
# 1            Connor McCarty       Chris Scarpa      CloudRetail
# 2              Siyaa Munjal      Amanda Scheer      CloudRetail
# 3              Siyaa Munjal  Matthew Kulpinski      CloudRetail
# 4              Siyaa Munjal  Matthew Kulpinski      CloudRetail
# ...                     ...                ...              ...
# 66015  Christopher Schwartz       Ariana Winer      CloudRetail
# 66016  Christopher Schwartz       Ariana Winer      CloudRetail
# 66017  Christopher Schwartz    Gabriela Osorio      CloudRetail
# 66018      Mitchell Mendoza      Zakary Garcia      CloudRetail
# 66019       Esteban Cardona       Ariana Winer      CloudRetail
#
#                   lead_ID Created_by_Title__c    Created_By_Role__c  \
# 0      00Q5G00000Sfy6lUAB               LATAM      Sales Operations
# 1      00Q5G00000SgdK8UAJ                None  US Account Executive
# 2      00Q5G00000SgdjxUAB   Marketing Manager           Super Admin
# 3      00Q5G00000SgkGqUAJ   Marketing Manager           Super Admin
# 4      00Q5G00000SgkP9UAJ   Marketing Manager           Super Admin
# ...                   ...                 ...                   ...
# 66015  00Qf400000S8SEgEAN                None           Super Admin
# 66016  00Qf400000S9qtSEAR                None           Super Admin
# 66017  00Qf400000SACylEAH                None           Super Admin
# 66018  00Qf400000SApFgEAL                None           Super Admin
# 66019  00Qf400000Sf6XUEAZ               LATAM      Sales Operations
#
#       Created_by_Manager__c                             Name  \
# 0             Barbara Garza           Carmen Sanguino Gamboa
# 1                Jack Green                    Marla Topliff
# 2           Jacques de Haes                     Modupe jacob
# 3           Jacques de Haes       FIrst Name Citron Catering
# 4           Jacques de Haes  first name Fire & Wine Catering
# ...                     ...                              ...
# 66015                  None                    Alicia Zuñiga
# 66016                  None                 Eduardo Bautista
# 66017                  None                Sebastian Mompala
# 66018         Sathya Murthy                   Shera Fournier
# 66019         Barbara Garza                   Nohemi Enguilo
#
#       Kitchen_Country__c Kitchen_City__c               Company  \
# 0                 Mexico     Mexico City          Littleponkis
# 1                   None         Chicago          Suzy's Swirl
# 2          United States         Atlanta         nifty fingers
# 3          United States     Los Angeles       Citron Catering
# 4          United States     Los Angeles  Fire & Wine Catering
# ...                  ...             ...                   ...
# 66015             Mexico     Mexico City      El Queso Gourmet
# 66016             Mexico     Mexico City            House cake
# 66017             Mexico     Mexico City      Café one chingon
# 66018      United States     Los Angeles                 Veron
# 66019             Mexico     Mexico City            Pastelitos
#
#                                 Email           Create_Date_Time__c  \
# 0        carmensanguino1315@gmail.com  2020-11-08T22:02:52.000+0000
# 1                marla@suzysswirl.com  2020-11-13T01:24:58.000+0000
# 2              modupe.jacob@gmail.com  2020-11-13T04:04:22.000+0000
# 3      contactus@citroncateringaz.com  2020-11-13T17:44:58.000+0000
# 4       fireandwinecatering@gmail.com  2020-11-13T17:45:13.000+0000
# ...                               ...                           ...
# 66015             lazwittig@gmail.com  2020-10-19T03:46:51.000+0000
# 66016            lalo.23hc@icloud.com  2020-10-22T21:52:15.000+0000
# 66017              smompala@gmail.com  2020-10-24T21:29:40.000+0000
# 66018          sfournier@theveron.com  2020-10-28T06:37:00.000+0000
# 66019       nohemi_enguilo@icloud.com  2020-11-02T15:28:07.000+0000
#
#                         CreatedDate     Lead_Owner_Country__c  \
# 0      2020-11-08T22:02:52.000+0000  United States of America
# 1      2020-11-13T01:24:58.000+0000  United States of America
# 2      2020-11-13T04:04:22.000+0000  United States of America
# 3      2020-11-13T17:44:58.000+0000                       USA
# 4      2020-11-13T17:45:13.000+0000                       USA
# ...                             ...                       ...
# 66015  2020-10-19T03:46:51.000+0000  United States of America
# 66016  2020-10-22T21:52:15.000+0000  United States of America
# 66017  2020-10-24T21:29:40.000+0000  United States of America
# 66018  2020-10-28T06:37:00.000+0000  United States of America
# 66019  2020-11-02T15:28:07.000+0000  United States of America
#
#                         Lead_Owner_Role__c Lead_Unqualified_Date__c  \
# 0                      US Customer Success                     None
# 1      Sales Development Representative CR                     None
# 2                     US Account Executive                     None
# 3                     US Account Executive                     None
# 4                     US Account Executive               2022-07-29
# ...                                    ...                      ...
# 66015                     US Sales Manager                     None
# 66016                     US Sales Manager                     None
# 66017                  US Customer Success                     None
# 66018          CR - Account Executive (AE)                     None
# 66019                     US Sales Manager               2022-05-17
#
#       Qualified_Date__c SalesLoft1__Most_Recent_Cadence_Name__c  \
# 0                  None       Inbound Virtual Kitchens - Mexico
# 1                  None                         Lead/Qualifying
# 2                  None                           after inbound
# 3                  None                                    None
# 4                  None        LA Katy Perry's Cadence 🎆 - mike
# ...                 ...                                     ...
# 66015              None       Inbound Virtual Kitchens - Mexico
# 66016              None       Inbound Virtual Kitchens - Mexico
# 66017              None       Inbound Virtual Kitchens - Mexico
# 66018              None             SDR - Inbound Cadence (v.2)
# 66019              None            SDR MX - Inbound CloudRetail
#
#                           LeadSource                  Status  \
# 0                  Inbound: Facebook               Qualified
# 1      Outbound: Targeted email/call                     New
# 2                  Inbound: Facebook  Closed - Not Converted
# 3                Data Science Scrape                     New
# 4                Data Science Scrape  Closed - Not Converted
# ...                              ...                     ...
# 66015               Inbound: Website               Qualified
# 66016               Inbound: Website               Qualified
# 66017                 Inbound: Other          Not Interested
# 66018         Inbound: Google Search  Closed - Not Converted
# 66019              Inbound: Facebook  Closed - Not Converted
#
#        Time_to_covert_to_Opp__c     Lead_Closed_Reason__c  \
# 0                           1.0                      None
# 1                           NaN                      None
# 2                           NaN       Disconnected Number
# 3                           NaN                      None
# 4                           NaN             Did Not Reach
# ...                         ...                       ...
# 66015                       3.0                      None
# 66016                       0.0                      None
# 66017                       NaN                      None
# 66018                       NaN  Not Interested - Pricing
# 66019                       NaN             Did Not Reach
#
#       Lead_Closed_Explanation__c         Campaign__c Campaign_Detail__c  \
# 0                           None  7015G000001hUN8QAM               None
# 1                           None                None               None
# 2                           None                None               None
# 3                           None                None               None
# 4                           None                None               None
# ...                          ...                 ...                ...
# 66015                       None  7015G000001hUN8QAM               None
# 66016                       None  7015G000001hUN8QAM               None
# 66017                       None  7015G000000kdneQAA               None
# 66018                       None                None               None
# 66019                       None                None               None
#
#        Refreshed_Lead__c Refreshed_Date__c  Days_Since_Last_Activity__c  \
# 0                  False              None                          NaN
# 1                  False              None                        131.0
# 2                  False              None                        542.0
# 3                  False              None                          NaN
# 4                  False              None                         61.0
# ...                  ...               ...                          ...
# 66015              False              None                          NaN
# 66016              False              None                          NaN
# 66017               True              None                        980.0
# 66018              False              None                        496.0
# 66019              False              None                        427.0
#
#        Days_Since_Last_Call__c Assigned_Date__c       First_Call_Date_Time__c  \
# 0                        966.0             None  2020-11-09T17:57:03.000+0000
# 1                        136.0             None  2023-02-13T18:45:29.000+0000
# 2                        542.0       2022-02-22  2020-12-03T15:28:29.000+0000
# 3                        962.0             None                          None
# 4                        962.0             None                          None
# ...                        ...              ...                           ...
# 66015                    988.0             None                          None
# 66016                    984.0             None                          None
# 66017                    982.0             None                          None
# 66018                    831.0             None  2020-10-30T00:03:27.000+0000
# 66019                    973.0             None                          None
#
#        Lead_Processed__c  of_Activities_Till_Convert__c  \
# 0                   True                            2.0
# 1                  False                            6.0
# 2                   True                            1.0
# 3                  False                            0.0
# 4                   True                           14.0
# ...                  ...                            ...
# 66015               True                            0.0
# 66016               True                            1.0
# 66017               True                            3.0
# 66018               True                            1.0
# 66019               True                            1.0
#
#        of_Calls_till_convert__c
# 0                           1.0
# 1                           2.0
# 2                           1.0
# 3                           0.0
# 4                           0.0
# ...                         ...
# 66015                       NaN
# 66016                       NaN
# 66017                       0.0
# 66018                       0.0
# 66019                       0.0
#
# [66020 rows x 35 columns]

# %%
leads_exp_2['First_Call_Date_Time__c']=pd.to_datetime(leads_exp_2['First_Call_Date_Time__c'],errors='coerce')

# %%
leads_exp_2['Create_Date_Time__c']=pd.to_datetime(leads_exp_2['Create_Date_Time__c'], errors='coerce')

# %%
leads_exp_2['CreatedDate']=pd.to_datetime(leads_exp_2['CreatedDate'], errors='coerce')

# %%
leads_exp_2['Lead_Unqualified_Date__c']=pd.to_datetime(leads_exp_2['Lead_Unqualified_Date__c'], errors='coerce')

# %%
#leads_exp_2['Lead_Converted_date__c']=pd.to_datetime(leads_exp_2['Lead_Converted_date__c'], errors='coerce')

# %%
leads_exp_2['Refreshed_Date__c']=pd.to_datetime(leads_exp_2['Refreshed_Date__c'], errors='coerce')

# %%
leads_exp_2['Assigned_Date__c']=pd.to_datetime(leads_exp_2['Assigned_Date__c'], errors='coerce')

# %%
leads_exp_2['CreatedDate_only_date']=pd.to_datetime(leads_exp_2['CreatedDate'], errors='coerce').dt.date

# %%
leads_exp_2
# Out:
#              CreatedBy_name         owner_name record_type_name  \
# 0           Esteban Cardona    Gabriela Osorio      CloudRetail
# 1            Connor McCarty       Chris Scarpa      CloudRetail
# 2              Siyaa Munjal      Amanda Scheer      CloudRetail
# 3              Siyaa Munjal  Matthew Kulpinski      CloudRetail
# 4              Siyaa Munjal  Matthew Kulpinski      CloudRetail
# ...                     ...                ...              ...
# 66015  Christopher Schwartz       Ariana Winer      CloudRetail
# 66016  Christopher Schwartz       Ariana Winer      CloudRetail
# 66017  Christopher Schwartz    Gabriela Osorio      CloudRetail
# 66018      Mitchell Mendoza      Zakary Garcia      CloudRetail
# 66019       Esteban Cardona       Ariana Winer      CloudRetail
#
#                   lead_ID Created_by_Title__c    Created_By_Role__c  \
# 0      00Q5G00000Sfy6lUAB               LATAM      Sales Operations
# 1      00Q5G00000SgdK8UAJ                None  US Account Executive
# 2      00Q5G00000SgdjxUAB   Marketing Manager           Super Admin
# 3      00Q5G00000SgkGqUAJ   Marketing Manager           Super Admin
# 4      00Q5G00000SgkP9UAJ   Marketing Manager           Super Admin
# ...                   ...                 ...                   ...
# 66015  00Qf400000S8SEgEAN                None           Super Admin
# 66016  00Qf400000S9qtSEAR                None           Super Admin
# 66017  00Qf400000SACylEAH                None           Super Admin
# 66018  00Qf400000SApFgEAL                None           Super Admin
# 66019  00Qf400000Sf6XUEAZ               LATAM      Sales Operations
#
#       Created_by_Manager__c                             Name  \
# 0             Barbara Garza           Carmen Sanguino Gamboa
# 1                Jack Green                    Marla Topliff
# 2           Jacques de Haes                     Modupe jacob
# 3           Jacques de Haes       FIrst Name Citron Catering
# 4           Jacques de Haes  first name Fire & Wine Catering
# ...                     ...                              ...
# 66015                  None                    Alicia Zuñiga
# 66016                  None                 Eduardo Bautista
# 66017                  None                Sebastian Mompala
# 66018         Sathya Murthy                   Shera Fournier
# 66019         Barbara Garza                   Nohemi Enguilo
#
#       Kitchen_Country__c Kitchen_City__c               Company  \
# 0                 Mexico     Mexico City          Littleponkis
# 1                   None         Chicago          Suzy's Swirl
# 2          United States         Atlanta         nifty fingers
# 3          United States     Los Angeles       Citron Catering
# 4          United States     Los Angeles  Fire & Wine Catering
# ...                  ...             ...                   ...
# 66015             Mexico     Mexico City      El Queso Gourmet
# 66016             Mexico     Mexico City            House cake
# 66017             Mexico     Mexico City      Café one chingon
# 66018      United States     Los Angeles                 Veron
# 66019             Mexico     Mexico City            Pastelitos
#
#                                 Email       Create_Date_Time__c  \
# 0        carmensanguino1315@gmail.com 2020-11-08 22:02:52+00:00
# 1                marla@suzysswirl.com 2020-11-13 01:24:58+00:00
# 2              modupe.jacob@gmail.com 2020-11-13 04:04:22+00:00
# 3      contactus@citroncateringaz.com 2020-11-13 17:44:58+00:00
# 4       fireandwinecatering@gmail.com 2020-11-13 17:45:13+00:00
# ...                               ...                       ...
# 66015             lazwittig@gmail.com 2020-10-19 03:46:51+00:00
# 66016            lalo.23hc@icloud.com 2020-10-22 21:52:15+00:00
# 66017              smompala@gmail.com 2020-10-24 21:29:40+00:00
# 66018          sfournier@theveron.com 2020-10-28 06:37:00+00:00
# 66019       nohemi_enguilo@icloud.com 2020-11-02 15:28:07+00:00
#
#                     CreatedDate     Lead_Owner_Country__c  \
# 0     2020-11-08 22:02:52+00:00  United States of America
# 1     2020-11-13 01:24:58+00:00  United States of America
# 2     2020-11-13 04:04:22+00:00  United States of America
# 3     2020-11-13 17:44:58+00:00                       USA
# 4     2020-11-13 17:45:13+00:00                       USA
# ...                         ...                       ...
# 66015 2020-10-19 03:46:51+00:00  United States of America
# 66016 2020-10-22 21:52:15+00:00  United States of America
# 66017 2020-10-24 21:29:40+00:00  United States of America
# 66018 2020-10-28 06:37:00+00:00  United States of America
# 66019 2020-11-02 15:28:07+00:00  United States of America
#
#                         Lead_Owner_Role__c Lead_Unqualified_Date__c  \
# 0                      US Customer Success                      NaT
# 1      Sales Development Representative CR                      NaT
# 2                     US Account Executive                      NaT
# 3                     US Account Executive                      NaT
# 4                     US Account Executive               2022-07-29
# ...                                    ...                      ...
# 66015                     US Sales Manager                      NaT
# 66016                     US Sales Manager                      NaT
# 66017                  US Customer Success                      NaT
# 66018          CR - Account Executive (AE)                      NaT
# 66019                     US Sales Manager               2022-05-17
#
#       Qualified_Date__c SalesLoft1__Most_Recent_Cadence_Name__c  \
# 0                  None       Inbound Virtual Kitchens - Mexico
# 1                  None                         Lead/Qualifying
# 2                  None                           after inbound
# 3                  None                                    None
# 4                  None        LA Katy Perry's Cadence 🎆 - mike
# ...                 ...                                     ...
# 66015              None       Inbound Virtual Kitchens - Mexico
# 66016              None       Inbound Virtual Kitchens - Mexico
# 66017              None       Inbound Virtual Kitchens - Mexico
# 66018              None             SDR - Inbound Cadence (v.2)
# 66019              None            SDR MX - Inbound CloudRetail
#
#                           LeadSource                  Status  \
# 0                  Inbound: Facebook               Qualified
# 1      Outbound: Targeted email/call                     New
# 2                  Inbound: Facebook  Closed - Not Converted
# 3                Data Science Scrape                     New
# 4                Data Science Scrape  Closed - Not Converted
# ...                              ...                     ...
# 66015               Inbound: Website               Qualified
# 66016               Inbound: Website               Qualified
# 66017                 Inbound: Other          Not Interested
# 66018         Inbound: Google Search  Closed - Not Converted
# 66019              Inbound: Facebook  Closed - Not Converted
#
#        Time_to_covert_to_Opp__c     Lead_Closed_Reason__c  \
# 0                           1.0                      None
# 1                           NaN                      None
# 2                           NaN       Disconnected Number
# 3                           NaN                      None
# 4                           NaN             Did Not Reach
# ...                         ...                       ...
# 66015                       3.0                      None
# 66016                       0.0                      None
# 66017                       NaN                      None
# 66018                       NaN  Not Interested - Pricing
# 66019                       NaN             Did Not Reach
#
#       Lead_Closed_Explanation__c         Campaign__c Campaign_Detail__c  \
# 0                           None  7015G000001hUN8QAM               None
# 1                           None                None               None
# 2                           None                None               None
# 3                           None                None               None
# 4                           None                None               None
# ...                          ...                 ...                ...
# 66015                       None  7015G000001hUN8QAM               None
# 66016                       None  7015G000001hUN8QAM               None
# 66017                       None  7015G000000kdneQAA               None
# 66018                       None                None               None
# 66019                       None                None               None
#
#        Refreshed_Lead__c Refreshed_Date__c  Days_Since_Last_Activity__c  \
# 0                  False               NaT                          NaN
# 1                  False               NaT                        131.0
# 2                  False               NaT                        542.0
# 3                  False               NaT                          NaN
# 4                  False               NaT                         61.0
# ...                  ...               ...                          ...
# 66015              False               NaT                          NaN
# 66016              False               NaT                          NaN
# 66017               True               NaT                        980.0
# 66018              False               NaT                        496.0
# 66019              False               NaT                        427.0
#
#        Days_Since_Last_Call__c Assigned_Date__c   First_Call_Date_Time__c  \
# 0                        966.0              NaT 2020-11-09 17:57:03+00:00
# 1                        136.0              NaT 2023-02-13 18:45:29+00:00
# 2                        542.0       2022-02-22 2020-12-03 15:28:29+00:00
# 3                        962.0              NaT                       NaT
# 4                        962.0              NaT                       NaT
# ...                        ...              ...                       ...
# 66015                    988.0              NaT                       NaT
# 66016                    984.0              NaT                       NaT
# 66017                    982.0              NaT                       NaT
# 66018                    831.0              NaT 2020-10-30 00:03:27+00:00
# 66019                    973.0              NaT                       NaT
#
#        Lead_Processed__c  of_Activities_Till_Convert__c  \
# 0                   True                            2.0
# 1                  False                            6.0
# 2                   True                            1.0
# 3                  False                            0.0
# 4                   True                           14.0
# ...                  ...                            ...
# 66015               True                            0.0
# 66016               True                            1.0
# 66017               True                            3.0
# 66018               True                            1.0
# 66019               True                            1.0
#
#        of_Calls_till_convert__c CreatedDate_only_date
# 0                           1.0            2020-11-08
# 1                           2.0            2020-11-13
# 2                           1.0            2020-11-13
# 3                           0.0            2020-11-13
# 4                           0.0            2020-11-13
# ...                         ...                   ...
# 66015                       NaN            2020-10-19
# 66016                       NaN            2020-10-22
# 66017                       0.0            2020-10-24
# 66018                       0.0            2020-10-28
# 66019                       0.0            2020-11-02
#
# [66020 rows x 36 columns]

# %%
from dateutil.relativedelta import relativedelta

# %%
hoy=datetime.datetime.today()

# %%
hoy
# Out:
# datetime.datetime(2023, 7, 3, 17, 58, 30, 175119)

# %%
fecha_6_meses=hoy+ relativedelta(months=-6)

# %%
fecha_6_meses.date()
# Out:
# datetime.date(2023, 1, 3)

# %%
leads_exp_2['CreatedDate']=pd.to_datetime(leads_exp_2['CreatedDate'], errors='coerce')

# %%
leads_exp_2['CreatedDate']
# Out:
# 0       2020-11-08 22:02:52+00:00
# 1       2020-11-13 01:24:58+00:00
# 2       2020-11-13 04:04:22+00:00
# 3       2020-11-13 17:44:58+00:00
# 4       2020-11-13 17:45:13+00:00
#                    ...
# 66015   2020-10-19 03:46:51+00:00
# 66016   2020-10-22 21:52:15+00:00
# 66017   2020-10-24 21:29:40+00:00
# 66018   2020-10-28 06:37:00+00:00
# 66019   2020-11-02 15:28:07+00:00
# Name: CreatedDate, Length: 66020, dtype: datetime64[ns, UTC]

# %%
leads_6_meses=leads_exp_2[leads_exp_2['CreatedDate'].dt.date>=fecha_6_meses.date()].reset_index(drop=True)

# %%
leads_6_meses
# Out:
#        CreatedBy_name       owner_name record_type_name             lead_ID  \
# 0        Bayne Hagood     Bayne Hagood      CloudRetail  00Q6T00001EfsFCUAZ
# 1        Neil Sampson     Neil Sampson      CloudRetail  00Q6T00001EfvE2UAJ
# 2        Neil Sampson     Neil Sampson      CloudRetail  00Q6T00001EfvElUAJ
# 3        Neil Sampson     Neil Sampson      CloudRetail  00Q6T00001EfvFPUAZ
# 4        Neil Sampson     Neil Sampson      CloudRetail  00Q6T00001EfvFeUAJ
# ...               ...              ...              ...                 ...
# 2409     Neil Sampson     Neil Sampson      CloudRetail  00Q6T00001I1WWsUAN
# 2410     Neil Sampson     Neil Sampson      CloudRetail  00Q6T00001I1WakUAF
# 2411     Neil Sampson     Neil Sampson      CloudRetail  00Q6T00001I1Ww2UAF
# 2412  Ronnie Muhammad  Ronnie Muhammad      CloudRetail  00Q6T00001I1b6hUAB
# 2413  Ronnie Muhammad  Ronnie Muhammad      CloudRetail  00Q6T00001I1bATUAZ
#
#                    Created_by_Title__c                   Created_By_Role__c  \
# 0     Sales Development Representative  Sales Development Representative CR
# 1                    Account Executive          CR - Account Executive (AE)
# 2                    Account Executive          CR - Account Executive (AE)
# 3                    Account Executive          CR - Account Executive (AE)
# 4                    Account Executive          CR - Account Executive (AE)
# ...                                ...                                  ...
# 2409                 Account Executive          CR - Account Executive (AE)
# 2410                 Account Executive          CR - Account Executive (AE)
# 2411                 Account Executive          CR - Account Executive (AE)
# 2412                 Account Executive          CR - Account Executive (AE)
# 2413                 Account Executive          CR - Account Executive (AE)
#
#      Created_by_Manager__c                      Name Kitchen_Country__c  \
# 0             Bryon Craven  Rebecca's Mighty Muffins      United States
# 1             Bryon Craven       Get Baked With Cass      United States
# 2             Bryon Craven  Crinkle Crackle Bakeshop      United States
# 3             Bryon Craven           Sweets & Treatz      United States
# 4             Bryon Craven      Mochata Baked Donuts               None
# ...                    ...                       ...                ...
# 2409          Bryon Craven  Sugar Mama's Cupcakes LA      United States
# 2410          Bryon Craven            Chunky Hunnies      United States
# 2411          Bryon Craven             Chunk- N-Chip      United States
# 2412          Bryon Craven                        NA      United States
# 2413          Bryon Craven                        NA      United States
#
#      Kitchen_City__c                   Company  \
# 0      San Francisco  Rabecca's Mighty Muffins
# 1               None       Get Baked With Cass
# 2               None  Crinkle Crackle Bakeshop
# 3               None           Sweets & Treatz
# 4               None                   Mochata
# ...              ...                       ...
# 2409     Los Angeles  Sugar Mama's Cupcakes LA
# 2410     Los Angeles            Chunky Hunnies
# 2411   Orange County              Chunk-N-Chip
# 2412         Chicago       Sugar Shack Chicago
# 2413         Chicago             Blazed Bakery
#
#                                  Email       Create_Date_Time__c  \
# 0          rebeccamuffin@sbcglobal.net 2023-01-03 15:47:50+00:00
# 1           getbakedwithcass@gmail.com 2023-01-04 06:14:15+00:00
# 2     crinklecracklebakeshop@gmail.com 2023-01-04 06:17:34+00:00
# 3             sweetsndtreatz@gmail.com 2023-01-04 06:22:54+00:00
# 4             mochataphambam@gmail.com 2023-01-04 06:25:14+00:00
# ...                                ...                       ...
# 2409    sugarmamascupcakesla@gmail.com 2023-06-26 18:36:27+00:00
# 2410           hello@chunkyhunnies.com 2023-06-26 18:53:50+00:00
# 2411           catering@chunknchip.com 2023-06-26 20:33:04+00:00
# 2412           sugarshack630@gmail.com 2023-06-27 23:40:00+00:00
# 2413             info@blazedbakery.net 2023-06-27 23:59:05+00:00
#
#                    CreatedDate     Lead_Owner_Country__c  \
# 0    2023-01-03 15:47:50+00:00  United States of America
# 1    2023-01-04 06:14:15+00:00  United States of America
# 2    2023-01-04 06:17:34+00:00  United States of America
# 3    2023-01-04 06:22:54+00:00  United States of America
# 4    2023-01-04 06:25:14+00:00  United States of America
# ...                        ...                       ...
# 2409 2023-06-26 18:36:27+00:00  United States of America
# 2410 2023-06-26 18:53:50+00:00  United States of America
# 2411 2023-06-26 20:33:04+00:00  United States of America
# 2412 2023-06-27 23:40:00+00:00  United States of America
# 2413 2023-06-27 23:59:05+00:00  United States of America
#
#                        Lead_Owner_Role__c Lead_Unqualified_Date__c  \
# 0     Sales Development Representative CR                      NaT
# 1             CR - Account Executive (AE)                      NaT
# 2             CR - Account Executive (AE)               2023-02-14
# 3             CR - Account Executive (AE)                      NaT
# 4             CR - Account Executive (AE)                      NaT
# ...                                   ...                      ...
# 2409          CR - Account Executive (AE)                      NaT
# 2410          CR - Account Executive (AE)                      NaT
# 2411          CR - Account Executive (AE)                      NaT
# 2412          CR - Account Executive (AE)                      NaT
# 2413          CR - Account Executive (AE)                      NaT
#
#      Qualified_Date__c SalesLoft1__Most_Recent_Cadence_Name__c  \
# 0                 None                         Lead/Qualifying
# 1                 None           Neil Sampson Bay Area Cadence
# 2                 None           Neil Sampson Bay Area Cadence
# 3                 None           Neil Sampson Bay Area Cadence
# 4                 None           Neil Sampson Bay Area Cadence
# ...                ...                                     ...
# 2409              None                                    None
# 2410              None                                    None
# 2411              None                                    None
# 2412              None                                    None
# 2413              None                                    None
#
#                       LeadSource                  Status  \
# 0     CR - Outbound Data Science               Qualified
# 1               CR - Outbound AE                 Working
# 2               CR - Outbound AE  Closed - Not Converted
# 3               CR - Outbound AE                 Working
# 4               CR - Outbound AE                     New
# ...                          ...                     ...
# 2409            CR - Outbound AE                     New
# 2410            CR - Outbound AE               Qualified
# 2411            CR - Outbound AE               Qualified
# 2412            CR - Outbound AE               Qualified
# 2413            CR - Outbound AE               Qualified
#
#       Time_to_covert_to_Opp__c Lead_Closed_Reason__c  \
# 0                          2.0                  None
# 1                          NaN                  None
# 2                          NaN         Did Not Reach
# 3                          NaN                  None
# 4                          NaN                  None
# ...                        ...                   ...
# 2409                       NaN                  None
# 2410                       0.0                  None
# 2411                       0.0                  None
# 2412                       0.0                  None
# 2413                       0.0                  None
#
#      Lead_Closed_Explanation__c Campaign__c Campaign_Detail__c  \
# 0                          None        None               None
# 1                          None        None               None
# 2                          None        None               None
# 3                          None        None               None
# 4                          None        None               None
# ...                         ...         ...                ...
# 2409                       None        None               None
# 2410                       None        None               None
# 2411                       None        None               None
# 2412                       None        None               None
# 2413                       None        None               None
#
#       Refreshed_Lead__c Refreshed_Date__c  Days_Since_Last_Activity__c  \
# 0                 False               NaT                          NaN
# 1                 False               NaT                        137.0
# 2                 False               NaT                         95.0
# 3                 False               NaT                        103.0
# 4                 False               NaT                        103.0
# ...                 ...               ...                          ...
# 2409              False               NaT                          NaN
# 2410              False               NaT                          NaN
# 2411              False               NaT                          NaN
# 2412              False               NaT                          NaN
# 2413              False               NaT                          NaN
#
#       Days_Since_Last_Call__c Assigned_Date__c   First_Call_Date_Time__c  \
# 0                       179.0              NaT 2023-01-03 21:02:20+00:00
# 1                       181.0              NaT                       NaT
# 2                        95.0              NaT 2023-01-06 21:22:05+00:00
# 3                       104.0              NaT 2023-01-06 21:13:39+00:00
# 4                       104.0              NaT 2023-01-06 21:11:50+00:00
# ...                       ...              ...                       ...
# 2409                      7.0              NaT                       NaT
# 2410                      7.0              NaT                       NaT
# 2411                      7.0              NaT                       NaT
# 2412                      6.0              NaT                       NaT
# 2413                      6.0              NaT                       NaT
#
#       Lead_Processed__c  of_Activities_Till_Convert__c  \
# 0                  True                            4.0
# 1                 False                            9.0
# 2                  True                            7.0
# 3                 False                           15.0
# 4                 False                           14.0
# ...                 ...                            ...
# 2409              False                            0.0
# 2410               True                            0.0
# 2411               True                            0.0
# 2412               True                            0.0
# 2413               True                            0.0
#
#       of_Calls_till_convert__c CreatedDate_only_date
# 0                          3.0            2023-01-03
# 1                          0.0            2023-01-04
# 2                          4.0            2023-01-04
# 3                          6.0            2023-01-04
# 4                          5.0            2023-01-04
# ...                        ...                   ...
# 2409                       0.0            2023-06-26
# 2410                       0.0            2023-06-26
# 2411                       0.0            2023-06-26
# 2412                       0.0            2023-06-27
# 2413                       0.0            2023-06-27
#
# [2414 rows x 36 columns]

# %%
import pygsheets
# Everything ready to upload to GSheets

## GSheets Oauth
print('Init Auth')
gc = pygsheets.authorize(service_file='/home/ruben.lopez/creds_spread.json')
# Out:
# Init Auth

# %%
## GSheets Oauth
print('Init Auth')
gc = pygsheets.authorize(service_file='/home/ruben.lopez/creds_spread.json')


# open the spreedsheet
print('Opening Spreadsheet')

ss = gc.open_by_key('17VX1EwaZRDAdPI2KkWk7jTXHPuA9FjMaUiIn53JxML8')

# select sheet

ws = ss.worksheet('title','leads')

print('Clearing Range ...')
ws.clear(start='A', end='AI')
print('Range CLEARED')

print('Pasting Info ...')
ws.set_dataframe(leads_6_meses, start="A1",copy_head=True, extend=True, nan= '' )
print('UPDATED!!')
# Out:
# Init Auth
# Opening Spreadsheet
# Clearing Range ...
# Range CLEARED
# Pasting Info ...
# UPDATED!!

# %%
## GSheets Oauth
print('Init Auth')
gc = pygsheets.authorize(service_file='/home/ruben.lopez/creds_spread.json')


# open the spreedsheet
print('Opening Spreadsheet')

ss = gc.open_by_key('1SjBzDiaFzEm8Rc2nOBtp-gNvI16qNzyZN1l1l10pUKs')

# select sheet

ws = ss.worksheet('title','leads')

print('Clearing Range ...')
ws.clear(start='A', end='AI')
print('Range CLEARED')

print('Pasting Info ...')
ws.set_dataframe(leads_6_meses, start="A1",copy_head=True, extend=True, nan= '' )
print('UPDATED!!')
# Out:
# Init Auth
# Opening Spreadsheet
# Clearing Range ...
# Range CLEARED
# Pasting Info ...
# UPDATED!!

# %%
from google.oauth2 import service_account
from google.cloud import bigquery

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]='/home/ruben.lopez/css-operations.json'
key_path = '/home/ruben.lopez/css-operations.json'
credentials = service_account.Credentials.from_service_account_file(key_path, scopes = ["https://www.googleapis.com/auth/cloud-platform"])
client = bigquery.Client()

# %%
leads_exp_2.to_gbq(credentials = credentials ,
              destination_table='latam_cr_growth.leads_US',
              progress_bar = True,
              if_exists='replace'
              #if_exists='append'
                        )
# Out:
# 1it [00:11, 11.13s/it]

# %%
#opportunities
# ### oportunidades latam
query_opp = """

SELECT Id,account.Account_ID_18__c, account.Org_Id_Otter__c, Facility_ID__c, Campaign_Detail__c, Campaign__c, Campaign__r.Name,  LeadSource, Account_Name_Jira__c, account.Name, account.Account_Status__c, owner.Name, Opp_Owner_Role__c, Opp_Owner_Region__c, SDR_Name__c, createdby.Create_Date__c, Created_Date_Weekly_Reports__c,
Opp_Owner_Country__c, Createdby.Name, Scheduled_virtual_tour__c, Completed_virtual_tour__c, SQL_Team_Attribution__c, SQL_Date__c, Kitchen_Country__c, Lead_Created_Date__c, Name, Opportunity_Owner_Name__c, Scheduled_virtual_tour_Date__c, 
Cuisine_Type__c, Type, StageName, Days_In_Current_Stage__c, Facility_Name__c, Closed_Won_Date__c, Start_Date__c, End_Date__c, Renewal_Term_Length_Months__c,  
Onboarding_Fee__c, Deposit_Fee__c, Activation_Fee_Dollar__c,
Processing_Fee__c, Monthly_License_Fee__c, Storage_Amount_Cold_CU_FT__c, Storage_Amount_Dry_CU_FT__c, Storage_Amount_Frozen_CU_FT__c, Monthly_Shelf_Fee_Cold_Storage__c, Monthly_Shelf_Fee_Dry_Storage__c, Monthly_Shelf_Fee_Frozen_Storage__c, 
CurrencyIsoCode, Access_Date__c, Activation_Date__c, Last_Activity__c, Last_Activity_Date__c, 
Is_Churned__c, Churn_Type__c, Primary_Churn_Reason__c, Churn_Reason__c, Churn_Date__c, 
FORMAT(convertCurrency(Monthly_Shelf_Fee_Frozen_Storage__c))shelf_frozen_fee_usd, 
FORMAT(convertCurrency(Monthly_Shelf_Fee_Dry_Storage__c))shelf_dry_fee_usd, 
FORMAT(convertCurrency(Monthly_Shelf_Fee_Cold_Storage__c))shelf_cold_fee_usd, 
Negotiation_Date__c, Qualifying_Date__c, Pitching_Date__c, Commitment_Date__c,
Hot_Level__c, Initial_Discount_Length__c, CloseDate,  Amount, LastModifiedDate,
SkuSku_Organization_ID__c, SkuSku_Facility_ID__c, Nurturing_Date__c,Loss_Reason__c,
Closed_Lost_Date__c,General_Lost_Reason__c,Previous_Stage__c,
Move_In_Date__c, Completed_in_person_tour__c, No_Show2__c, Access_Date_Checkbox__c, 
Specific_Lost_Reason__c, Lost_Explanation__c




from Opportunity  

where RecordType.Name in ('Virtual', 'CloudRetail','virtual;cloudretail') and Opp_Owner_Region__c in ('US/CAN')


"""


print('Getting User Data...')

# Query users to dataframe
opp = pd.DataFrame(sf.query_all(query_opp)['records'])
print('Users Pulled')

opp
# Out:
# Getting User Data...
# Users Pulled
#                                               attributes                  Id  \
# 0      {'type': 'Opportunity', 'url': '/services/data...  0066T00001A4WzzQAF
# 1      {'type': 'Opportunity', 'url': '/services/data...  0066T00001A4aOsQAJ
# 2      {'type': 'Opportunity', 'url': '/services/data...  0066T00001A4RVKQA3
# 3      {'type': 'Opportunity', 'url': '/services/data...  0066T00001A4aCmQAJ
# 4      {'type': 'Opportunity', 'url': '/services/data...  0066T00001A4hSKQAZ
# ...                                                  ...                 ...
# 10188  {'type': 'Opportunity', 'url': '/services/data...  0066T0000185QLlQAM
# 10189  {'type': 'Opportunity', 'url': '/services/data...  0065G00000YTrWpQAL
# 10190  {'type': 'Opportunity', 'url': '/services/data...  0065G00000YTrWzQAL
# 10191  {'type': 'Opportunity', 'url': '/services/data...  0065G00000j3iGfQAI
# 10192  {'type': 'Opportunity', 'url': '/services/data...  0065G00000YTrX9QAL
#
#                                                  Account      Facility_ID__c  \
# 0      {'attributes': {'type': 'Account', 'url': '/se...  001f400001IzqxKAAR
# 1      {'attributes': {'type': 'Account', 'url': '/se...  0015G00001cbBVQQA2
# 2      {'attributes': {'type': 'Account', 'url': '/se...                None
# 3      {'attributes': {'type': 'Account', 'url': '/se...  001f400001Ha9uKAAR
# 4      {'attributes': {'type': 'Account', 'url': '/se...  001f400000OM70XAAT
# ...                                                  ...                 ...
# 10188  {'attributes': {'type': 'Account', 'url': '/se...  001f400001Ha9uKAAR
# 10189  {'attributes': {'type': 'Account', 'url': '/se...  001f400000QNEbqAAH
# 10190  {'attributes': {'type': 'Account', 'url': '/se...  001f400001HXpI7AAL
# 10191  {'attributes': {'type': 'Account', 'url': '/se...  0015G00001dp0pwQAA
# 10192  {'attributes': {'type': 'Account', 'url': '/se...  001f400001OdWW5AAN
#
#       Campaign_Detail__c Campaign__c Campaign__r  \
# 0                   None        None        None
# 1                   None        None        None
# 2                   None        None        None
# 3                   None        None        None
# 4                   None        None        None
# ...                  ...         ...         ...
# 10188               None        None        None
# 10189               None        None        None
# 10190               None        None        None
# 10191               None        None        None
# 10192               None        None        None
#
#                           LeadSource                     Account_Name_Jira__c  \
# 0                Data Science Scrape                       Guanatos Ice Cream
# 1                   CR - Outbound AE  Ice Cream University Desserts - Correct
# 2       CR - Refresh (Re-engagement)                       Cheezcake Boutique
# 3         CR - Outbound Social Media                    The Bakehouse Chicago
# 4                Data Science Scrape               Sister My Sister Bake Shop
# ...                              ...                                      ...
# 10188               CR - Outbound AE              Sweet Temptations Bake Shop
# 10189                           None                        Bunch of Munchies
# 10190                           None                        Bunch of Munchies
# 10191  Outbound: Targeted email/call                           Khea's Cookies
# 10192                           None                        Bunch of Munchies
#
#                                                    Owner  \
# 0      {'attributes': {'type': 'User', 'url': '/servi...
# 1      {'attributes': {'type': 'User', 'url': '/servi...
# 2      {'attributes': {'type': 'User', 'url': '/servi...
# 3      {'attributes': {'type': 'User', 'url': '/servi...
# 4      {'attributes': {'type': 'User', 'url': '/servi...
# ...                                                  ...
# 10188  {'attributes': {'type': 'User', 'url': '/servi...
# 10189  {'attributes': {'type': 'User', 'url': '/servi...
# 10190  {'attributes': {'type': 'User', 'url': '/servi...
# 10191  {'attributes': {'type': 'User', 'url': '/servi...
# 10192  {'attributes': {'type': 'User', 'url': '/servi...
#
#                  Opp_Owner_Role__c Opp_Owner_Region__c         SDR_Name__c  \
# 0      CR - Account Executive (AE)              US/CAN                None
# 1      CR - Account Executive (AE)              US/CAN                None
# 2             Account Executive CR              US/CAN    Adam Schomberger
# 3             Account Executive CR              US/CAN  Christopher Scarpa
# 4      CR - Account Executive (AE)              US/CAN                None
# ...                            ...                 ...                 ...
# 10188         Account Executive CR              US/CAN                None
# 10189                         None              US/CAN                None
# 10190                         None              US/CAN                None
# 10191         Account Executive CR              US/CAN         Jaden Hills
# 10192  CR - Account Executive (AE)              US/CAN                None
#
#                                                CreatedBy  \
# 0      {'attributes': {'type': 'User', 'url': '/servi...
# 1      {'attributes': {'type': 'User', 'url': '/servi...
# 2      {'attributes': {'type': 'User', 'url': '/servi...
# 3      {'attributes': {'type': 'User', 'url': '/servi...
# 4      {'attributes': {'type': 'User', 'url': '/servi...
# ...                                                  ...
# 10188  {'attributes': {'type': 'User', 'url': '/servi...
# 10189  {'attributes': {'type': 'User', 'url': '/servi...
# 10190  {'attributes': {'type': 'User', 'url': '/servi...
# 10191  {'attributes': {'type': 'User', 'url': '/servi...
# 10192  {'attributes': {'type': 'User', 'url': '/servi...
#
#       Created_Date_Weekly_Reports__c      Opp_Owner_Country__c  \
# 0       2022-12-05T22:31:22.000+0000  United States of America
# 1       2022-12-06T17:46:21.000+0000  United States of America
# 2       2022-12-04T21:04:21.000+0000  United States of America
# 3       2022-12-06T17:12:20.000+0000  United States of America
# 4       2022-12-08T01:09:22.000+0000  United States of America
# ...                              ...                       ...
# 10188   2022-07-06T02:36:31.000+0000  United States of America
# 10189   2021-02-11T22:37:58.000+0000             United States
# 10190   2021-02-11T22:38:01.000+0000             United States
# 10191   2021-10-19T22:32:23.000+0000             United States
# 10192   2021-02-11T22:38:06.000+0000  United States of America
#
#        Scheduled_virtual_tour__c  Completed_virtual_tour__c  \
# 0                           True                       True
# 1                           True                       True
# 2                          False                      False
# 3                           True                       True
# 4                           True                       True
# ...                          ...                        ...
# 10188                      False                      False
# 10189                      False                      False
# 10190                      False                      False
# 10191                       True                       True
# 10192                      False                      False
#
#       SQL_Team_Attribution__c SQL_Date__c Kitchen_Country__c  \
# 0                        None  2022-12-15      United States
# 1                        None  2022-12-07      United States
# 2                        None        None      United States
# 3                        None  2022-12-07      United States
# 4                        None  2023-01-10      United States
# ...                       ...         ...                ...
# 10188                    None        None      United States
# 10189                    None        None      United States
# 10190                    None        None      United States
# 10191                    None  2021-10-25      United States
# 10192                    None        None      United States
#
#       Lead_Created_Date__c                                               Name  \
# 0               2022-08-09  Guanatos Ice Cream - SF - Lower Mission (Chart...
# 1               2022-12-07  Ice Cream University Desserts - NYC - Brooklyn...
# 2               2022-04-27                               Cheezcake Boutique -
# 3               2022-12-02  The Bakehouse Chicago - CHI - River West (Supe...
# 4               2021-07-14  Sister My Sister Bake Shop - LA - Pico Union (...
# ...                    ...                                                ...
# 10188           2022-05-25  Sweet Temptations Bake Shop - CHI - River West...
# 10189                 None       Bunch of Munchies - NA-US-CA(S)-LA-Hollywood
# 10190                 None       Bunch of Munchies - NA-US-CA(S)-LA-LongBeach
# 10191           2021-10-08         Khea's Cookies - TX - Dallas (Live Oak St)
# 10192                 None         Bunch of Munchies - NA-US-CA(S)-LA-Anaheim
#
#       Opportunity_Owner_Name__c Scheduled_virtual_tour_Date__c  \
# 0                  Neil Sampson                     2022-12-06
# 1                  Neil Sampson                     2022-12-07
# 2                   Alex Milkes                           None
# 3                   Alex Milkes                           None
# 4                 Zakary Garcia                     2022-12-08
# ...                         ...                            ...
# 10188          Michael DeBlasis                           None
# 10189               Dan Tadesse                           None
# 10190               Dan Tadesse                           None
# 10191              Albert Hayes                     2021-10-20
# 10192             Zakary Garcia                           None
#
#                                        Cuisine_Type__c                 Type  \
# 0      CR - Ice Cream, Popsicle, Cookie Dough & Gelato                 None
# 1      CR - Ice Cream, Popsicle, Cookie Dough & Gelato  US Monthly Contract
# 2                                                 None                 None
# 3                                                 None                 None
# 4                                     CR - Baked Goods                 None
# ...                                                ...                  ...
# 10188                                             None                 None
# 10189                                             None                 None
# 10190                                             None                 None
# 10191                                             None                 None
# 10192                                             None                 None
#
#          StageName  Days_In_Current_Stage__c             Facility_Name__c  \
# 0        Nurturing                     123.0                         None
# 1       Closed Won                     207.0                         None
# 2      Closed Lost                     110.0                         None
# 3      Closed Lost                      68.0                         None
# 4      Closed Lost                     127.0                         None
# ...            ...                       ...                          ...
# 10188  Closed Lost                     361.0  CHI - River West (Superior)
# 10189   Closed Won                       0.0     LA - Hollywood (Western)
# 10190   Closed Won                       0.0      LA - Long Beach (Daisy)
# 10191  Closed Lost                     495.0    TX - Dallas (Live Oak St)
# 10192   Closed Won                       0.0         LA - Anaheim (Lewis)
#
#       Closed_Won_Date__c Start_Date__c End_Date__c  \
# 0                   None          None        None
# 1             2022-12-08    2022-12-07  2023-12-07
# 2                   None          None        None
# 3                   None          None        None
# 4                   None          None        None
# ...                  ...           ...         ...
# 10188               None          None        None
# 10189         2020-12-11    2021-01-01  2021-12-31
# 10190         2020-12-11    2021-01-01  2021-12-31
# 10191               None          None        None
# 10192         2020-12-11    2021-01-01  2021-12-31
#
#        Renewal_Term_Length_Months__c  Onboarding_Fee__c  Deposit_Fee__c  \
# 0                                NaN                NaN             NaN
# 1                               12.0              500.0          1200.0
# 2                                NaN                NaN             NaN
# 3                                NaN                NaN             NaN
# 4                                NaN                NaN             NaN
# ...                              ...                ...             ...
# 10188                            NaN                NaN             NaN
# 10189                            NaN                0.0             0.0
# 10190                            NaN              500.0             0.0
# 10191                            NaN                NaN             NaN
# 10192                            NaN                0.0             0.0
#
#        Activation_Fee_Dollar__c  Processing_Fee__c  Monthly_License_Fee__c  \
# 0                        2500.0                NaN                     NaN
# 1                           0.0               15.0                     NaN
# 2                           0.0                NaN                     NaN
# 3                        2500.0                NaN                     NaN
# 4                        2500.0                NaN                     NaN
# ...                         ...                ...                     ...
# 10188                    2500.0                NaN                     NaN
# 10189                    7500.0               10.0                     NaN
# 10190                    2500.0               10.0                     NaN
# 10191                       0.0                NaN                     NaN
# 10192                    2500.0               15.0                     NaN
#
#        Storage_Amount_Cold_CU_FT__c  Storage_Amount_Dry_CU_FT__c  \
# 0                               NaN                          NaN
# 1                               0.0                          0.0
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
# ...                             ...                          ...
# 10188                           NaN                          NaN
# 10189                           0.0                         16.0
# 10190                           0.0                          8.0
# 10191                           NaN                          NaN
# 10192                           0.0                          8.0
#
#        Storage_Amount_Frozen_CU_FT__c  Monthly_Shelf_Fee_Cold_Storage__c  \
# 0                                 NaN                                NaN
# 1                                16.0                                0.0
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ...                               ...                                ...
# 10188                             NaN                                NaN
# 10189                             0.0                                0.0
# 10190                             0.0                                0.0
# 10191                             NaN                                NaN
# 10192                             0.0                                0.0
#
#        Monthly_Shelf_Fee_Dry_Storage__c  Monthly_Shelf_Fee_Frozen_Storage__c  \
# 0                                   NaN                                  NaN
# 1                                   0.0                                600.0
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# ...                                 ...                                  ...
# 10188                               NaN                                  NaN
# 10189                             250.0                                  0.0
# 10190                             125.0                                  0.0
# 10191                               NaN                                  NaN
# 10192                             125.0                                  0.0
#
#       CurrencyIsoCode Access_Date__c Activation_Date__c  \
# 0                 USD           None               None
# 1                 USD           None               None
# 2                 USD           None               None
# 3                 USD           None               None
# 4                 USD           None               None
# ...               ...            ...                ...
# 10188             USD           None               None
# 10189             USD           None               None
# 10190             USD           None               None
# 10191             USD           None               None
# 10192             USD           None               None
#
#                    Last_Activity__c Last_Activity_Date__c  Is_Churned__c  \
# 0      2023-06-27T19:00:00.000+0000            2023-06-27          False
# 1                              None            2022-12-15           True
# 2      2023-06-15T19:00:00.000+0000            2023-06-27          False
# 3      2023-03-23T19:00:00.000+0000            2023-06-21          False
# 4      2023-02-01T19:00:00.000+0000            2023-02-27          False
# ...                             ...                   ...            ...
# 10188  2022-07-07T19:00:00.000+0000            2023-06-21          False
# 10189                          None                  None           True
# 10190                          None                  None           True
# 10191  2022-06-20T19:00:00.000+0000            2023-03-03          False
# 10192                          None                  None           True
#
#                            Churn_Type__c             Primary_Churn_Reason__c  \
# 0                                   None                                None
# 1                              Transfers             CR - Change in Facility
# 2                                   None                                None
# 3                                   None                                None
# 4                                   None                                None
# ...                                  ...                                 ...
# 10188                               None                                None
# 10189  Early Termination (after move-in)  CR - Inventory Supply Chain Issues
# 10190  Early Termination (after move-in)  CR - Inventory Supply Chain Issues
# 10191                               None                                None
# 10192  Early Termination (after move-in)  CR - Inventory Supply Chain Issues
#
#       Churn_Reason__c Churn_Date__c shelf_frozen_fee_usd shelf_dry_fee_usd  \
# 0                None          None
# 1                None    2022-12-14        MXN 13,128.00          MXN 0.00
# 2                None          None
# 3                None          None
# 4                None          None
# ...               ...           ...                  ...               ...
# 10188            None          None
# 10189            None    2022-05-23             MXN 0.00      MXN 5,470.00
# 10190            None    2022-05-23             MXN 0.00      MXN 2,735.00
# 10191            None          None
# 10192            None    2022-05-23             MXN 0.00      MXN 2,735.00
#
#       shelf_cold_fee_usd Negotiation_Date__c Qualifying_Date__c  \
# 0                                       None         2022-12-06
# 1               MXN 0.00          2022-12-08         2022-12-07
# 2                                       None         2022-12-05
# 3                                       None         2022-12-07
# 4                                       None         2022-12-08
# ...                  ...                 ...                ...
# 10188                                   None         2022-07-06
# 10189           MXN 0.00                None         2021-02-12
# 10190           MXN 0.00                None         2021-02-12
# 10191                                   None         2021-10-20
# 10192           MXN 0.00                None         2021-02-12
#
#       Pitching_Date__c Commitment_Date__c Hot_Level__c  \
# 0           2023-02-01               None         None
# 1           2022-12-08         2022-12-08         None
# 2                 None               None         None
# 3                 None               None         None
# 4           2023-01-10               None         None
# ...                ...                ...          ...
# 10188             None               None         None
# 10189             None               None         None
# 10190             None               None         None
# 10191             None               None         None
# 10192             None               None         None
#
#        Initial_Discount_Length__c   CloseDate  Amount  \
# 0                             NaN  2023-01-06  5300.0
# 1                             NaN  2022-12-08  7700.0
# 2                             NaN  2023-03-15     NaN
# 3                             NaN  2023-04-26  4100.0
# 4                             NaN  2023-02-26  4700.0
# ...                           ...         ...     ...
# 10188                         NaN  2022-07-07     NaN
# 10189                         NaN  2020-12-11     NaN
# 10190                         NaN  2020-12-11     NaN
# 10191                         NaN  2022-02-23     NaN
# 10192                         NaN  2020-12-11     NaN
#
#                    LastModifiedDate SkuSku_Organization_ID__c  \
# 0      2023-06-27T20:55:53.000+0000                      None
# 1      2023-04-18T14:36:46.000+0000                      None
# 2      2023-06-27T18:03:58.000+0000                      None
# 3      2023-06-24T13:24:04.000+0000                      None
# 4      2023-05-21T19:18:34.000+0000                      None
# ...                             ...                       ...
# 10188  2023-06-14T01:07:45.000+0000                      None
# 10189  2023-04-03T20:17:26.000+0000                      None
# 10190  2023-04-03T20:17:27.000+0000                      None
# 10191  2022-06-22T20:48:56.000+0000                      None
# 10192  2023-04-03T20:17:26.000+0000                      None
#
#                       SkuSku_Facility_ID__c Nurturing_Date__c Loss_Reason__c  \
# 0      b0629713-f1bd-4d2b-a065-46ff82645987        2023-03-02           None
# 1      65820060-3a5f-4561-9f7a-9a7e34c581c1              None           None
# 2                                      None              None           None
# 3      75187d2a-01d8-467f-9993-90e200a3a586        2022-12-07           None
# 4      99573ac0-a3f2-4c70-946c-e9c06b425d5c        2023-01-10           None
# ...                                     ...               ...            ...
# 10188  75187d2a-01d8-467f-9993-90e200a3a586              None           None
# 10189  f0029277-0e7e-410a-ad4e-5247b892a280              None           None
# 10190  5315a66f-8337-4c68-af42-86089a86f8ba              None           None
# 10191  03cda0f8-198d-4951-91ae-75778fba72df              None           None
# 10192  9c7b97b6-878f-4007-9032-558c4c6157e9              None           None
#
#       Closed_Lost_Date__c General_Lost_Reason__c       Previous_Stage__c  \
# 0                    None                   None                Pitching
# 1                    None         Labor Concerns                Approved
# 2              2023-03-15              Duplicate              Qualifying
# 3              2023-04-26                Pricing               Nurturing
# 4              2023-02-26                Dormant                Approved
# ...                   ...                    ...                     ...
# 10188          2022-07-07                Concept              Qualifying
# 10189                None                   None                    None
# 10190                None                   None                    None
# 10191          2022-02-23      Stuck in Pipeline  Closed - Not Converted
# 10192                None                   None                    None
#
#       Move_In_Date__c  Completed_in_person_tour__c  No_Show2__c  \
# 0                None                        False        False
# 1                None                        False        False
# 2                None                        False        False
# 3                None                        False        False
# 4                None                        False        False
# ...               ...                          ...          ...
# 10188            None                        False         True
# 10189            None                        False        False
# 10190            None                        False        False
# 10191            None                        False        False
# 10192            None                        False        False
#
#        Access_Date_Checkbox__c Specific_Lost_Reason__c  \
# 0                         True                    None
# 1                         True                    None
# 2                         True                    None
# 3                         True                    None
# 4                         True                    None
# ...                        ...                     ...
# 10188                     True                    None
# 10189                     True                    None
# 10190                     True                    None
# 10191                     True                    None
# 10192                     True                    None
#
#                    Lost_Explanation__c
# 0                                 None
# 1                                 None
# 2                              old opp
# 3        couldn't get over the pricing
# 4                             small co
# ...                                ...
# 10188  Doesn't want to work with ofos.
# 10189                             None
# 10190                             None
# 10191                             None
# 10192                             None
#
# [10193 rows x 80 columns]

# %%
opp.columns
# Out:
# Index(['attributes', 'Id', 'Account', 'Facility_ID__c', 'Campaign_Detail__c',
#        'Campaign__c', 'Campaign__r', 'LeadSource', 'Account_Name_Jira__c',
#        'Owner', 'Opp_Owner_Role__c', 'Opp_Owner_Region__c', 'SDR_Name__c',
#        'CreatedBy', 'Created_Date_Weekly_Reports__c', 'Opp_Owner_Country__c',
#        'Scheduled_virtual_tour__c', 'Completed_virtual_tour__c',
#        'SQL_Team_Attribution__c', 'SQL_Date__c', 'Kitchen_Country__c',
#        'Lead_Created_Date__c', 'Name', 'Opportunity_Owner_Name__c',
#        'Scheduled_virtual_tour_Date__c', 'Cuisine_Type__c', 'Type',
#        'StageName', 'Days_In_Current_Stage__c', 'Facility_Name__c',
#        'Closed_Won_Date__c', 'Start_Date__c', 'End_Date__c',
#        'Renewal_Term_Length_Months__c', 'Onboarding_Fee__c', 'Deposit_Fee__c',
#        'Activation_Fee_Dollar__c', 'Processing_Fee__c',
#        'Monthly_License_Fee__c', 'Storage_Amount_Cold_CU_FT__c',
#        'Storage_Amount_Dry_CU_FT__c', 'Storage_Amount_Frozen_CU_FT__c',
#        'Monthly_Shelf_Fee_Cold_Storage__c', 'Monthly_Shelf_Fee_Dry_Storage__c',
#        'Monthly_Shelf_Fee_Frozen_Storage__c', 'CurrencyIsoCode',
#        'Access_Date__c', 'Activation_Date__c', 'Last_Activity__c',
#        'Last_Activity_Date__c', 'Is_Churned__c', 'Churn_Type__c',
#        'Primary_Churn_Reason__c', 'Churn_Reason__c', 'Churn_Date__c',
#        'shelf_frozen_fee_usd', 'shelf_dry_fee_usd', 'shelf_cold_fee_usd',
#        'Negotiation_Date__c', 'Qualifying_Date__c', 'Pitching_Date__c',
#        'Commitment_Date__c', 'Hot_Level__c', 'Initial_Discount_Length__c',
#        'CloseDate', 'Amount', 'LastModifiedDate', 'SkuSku_Organization_ID__c',
#        'SkuSku_Facility_ID__c', 'Nurturing_Date__c', 'Loss_Reason__c',
#        'Closed_Lost_Date__c', 'General_Lost_Reason__c', 'Previous_Stage__c',
#        'Move_In_Date__c', 'Completed_in_person_tour__c', 'No_Show2__c',
#        'Access_Date_Checkbox__c', 'Specific_Lost_Reason__c',
#        'Lost_Explanation__c'],
#       dtype='object')

# %%
#opp['Campaign__r'][7]

# %%
opp['Account'][5]
# Out:
# OrderedDict([('attributes',
#               OrderedDict([('type', 'Account'),
#                            ('url',
#                             '/services/data/v42.0/sobjects/Account/0016T00002xICm4QAG')])),
#              ('Account_ID_18__c', '0016T00002xICm4QAG'),
#              ('Org_Id_Otter__c', None),
#              ('Name', 'Schweet Cheesecake'),
#              ('Account_Status__c', 'Not Interested at this time')])

# %%
lista_campaign_name=[]
lista_account_name=[]
lista_status=[]
lista_id_18=[]
for i in range(len(opp)):
    try:
        valor=opp['Account'][i]['Name']
    except:
        valor='no_account_name'
    try:
        status=opp['Account'][i]['Account_Status__c']
    except:
        status='no_status'
    try:
        campa=opp['Campaign__r'][i]['Name']
    except:
        campa='no_campaign'
    try:
        id_18=opp['Account'][i]['Account_ID_18__c']
    except:
        id_18='no_id18'
    lista_account_name.append(valor)
    lista_status.append(status)
    lista_campaign_name.append(campa)
    lista_id_18.append(id_18)

# %%
opp['Account_name']=lista_account_name
opp['Account_status']=lista_status

# %%
opp['Account_ID18']=lista_id_18

# %%
opp['campaign_name']=lista_campaign_name

# %%
opp[['Account_name','Account_status','campaign_name','Account_ID18']]
# Out:
#                                   Account_name               Account_status  \
# 0                           Guanatos Ice Cream                    Nurturing
# 1      Ice Cream University Desserts - Correct             Current Customer
# 2                           Cheezcake Boutique                    Nurturing
# 3                        The Bakehouse Chicago                      Working
# 4                   Sister My Sister Bake Shop  Not Interested at this time
# ...                                        ...                          ...
# 10188              Sweet Temptations Bake Shop                      Working
# 10189                        Bunch of Munchies             Current Customer
# 10190                        Bunch of Munchies             Current Customer
# 10191                           Khea's Cookies  Not Interested at this time
# 10192                        Bunch of Munchies             Current Customer
#
#       campaign_name        Account_ID18
# 0       no_campaign  0016T00002xIQ5lQAG
# 1       no_campaign  0016T00002xJshdQAC
# 2       no_campaign  0016T00002xICfnQAG
# 3       no_campaign  0016T00002xIZYvQAO
# 4       no_campaign  0016T00002xIoDFQA0
# ...             ...                 ...
# 10188   no_campaign  0016T00002sDVF7QAO
# 10189   no_campaign  0015G00001a9QruQAE
# 10190   no_campaign  0015G00001a9QruQAE
# 10191   no_campaign  0015G00001p0bnTQAQ
# 10192   no_campaign  0015G00001a9QruQAE
#
# [10193 rows x 4 columns]

# %%
#opp['Account'][8]

# %%
opp['CreatedBy'][8]
# Out:
# OrderedDict([('attributes',
#               OrderedDict([('type', 'User'),
#                            ('url',
#                             '/services/data/v42.0/sobjects/User/0055G000006QsKuQAK')])),
#              ('Create_Date__c', '2021-09-06'),
#              ('Name', 'Chris Scarpa')])

# %%
#opp['Account'][8]['Org_Id_Otter__c']

# %%
lista_owner_name_2=[]
#lista_org_name_2
lista_org_id_2=[]
lista_created_name=[]
lista_created_date=[]
for i in range(len(opp)):
    try:
        valor=opp['Owner'][i]['Name']
        #org_name=opp['Account'][i]['Name']
        org_id=opp['Account'][i]['Org_Id_Otter__c']
        created_name=opp['CreatedBy'][i]['Name']
        created_date=opp['CreatedBy'][i]['Create_Date__c']
    except:
        valor='no_Owner_name'
        #org_name='no_org_name'
        org_id='no_org_id'
        created_name='no_Created_name'
        created_date='no_created_date'
    lista_owner_name_2.append(valor)
    #lista_org_name_2.append(org_name)
    lista_org_id_2.append(org_id)
    lista_created_name.append(created_name)
    lista_created_date.append(created_date)

# %%
opp['Owner_name']=lista_owner_name_2

# %%
opp['sfdc_org_id']=lista_org_id_2

# %%
opp['superset_org_id']=opp[['SkuSku_Organization_ID__c','sfdc_org_id']].bfill(axis=1).iloc[:, 0].fillna('no_org_id')

# %%
opp['created_by_name']=lista_created_name
opp['created_by_date']=lista_created_date

# %%
opp[['Account_name','Owner_name','superset_org_id','created_by_name','created_by_date']]
# Out:
#                                   Account_name        Owner_name  \
# 0                           Guanatos Ice Cream      Neil Sampson
# 1      Ice Cream University Desserts - Correct      Neil Sampson
# 2                           Cheezcake Boutique       Alex Milkes
# 3                        The Bakehouse Chicago       Alex Milkes
# 4                   Sister My Sister Bake Shop     Zakary Garcia
# ...                                        ...               ...
# 10188              Sweet Temptations Bake Shop  Michael DeBlasis
# 10189                        Bunch of Munchies       Dan Tadesse
# 10190                        Bunch of Munchies       Dan Tadesse
# 10191                           Khea's Cookies      Albert Hayes
# 10192                        Bunch of Munchies     Zakary Garcia
#
#                             superset_org_id   created_by_name created_by_date
# 0                                 no_org_id      Bayne Hagood      2022-09-06
# 1      56191d3b-4c83-43a9-88e4-2c6251afb3b7      Neil Sampson      2021-02-23
# 2      b096bf2e-7afd-4940-8f70-39c1b1d58bbc  Adam Schomberger      2022-08-08
# 3                                 no_org_id      Chris Scarpa      2021-09-06
# 4                                 no_org_id   Abdiel Beckford      2022-09-05
# ...                                     ...               ...             ...
# 10188                             no_org_id  Michael DeBlasis      2021-12-29
# 10189  cfdf1476-d106-4a24-8f27-0bbb2c2a29f4     Paulo Moreira      2020-10-13
# 10190  cfdf1476-d106-4a24-8f27-0bbb2c2a29f4     Paulo Moreira      2020-10-13
# 10191                             no_org_id       Jaden Hills      2021-07-14
# 10192  cfdf1476-d106-4a24-8f27-0bbb2c2a29f4     Paulo Moreira      2020-10-13
#
# [10193 rows x 5 columns]

# %%
opp.columns
# Out:
# Index(['attributes', 'Id', 'Account', 'Facility_ID__c', 'Campaign_Detail__c',
#        'Campaign__c', 'Campaign__r', 'LeadSource', 'Account_Name_Jira__c',
#        'Owner', 'Opp_Owner_Role__c', 'Opp_Owner_Region__c', 'SDR_Name__c',
#        'CreatedBy', 'Created_Date_Weekly_Reports__c', 'Opp_Owner_Country__c',
#        'Scheduled_virtual_tour__c', 'Completed_virtual_tour__c',
#        'SQL_Team_Attribution__c', 'SQL_Date__c', 'Kitchen_Country__c',
#        'Lead_Created_Date__c', 'Name', 'Opportunity_Owner_Name__c',
#        'Scheduled_virtual_tour_Date__c', 'Cuisine_Type__c', 'Type',
#        'StageName', 'Days_In_Current_Stage__c', 'Facility_Name__c',
#        'Closed_Won_Date__c', 'Start_Date__c', 'End_Date__c',
#        'Renewal_Term_Length_Months__c', 'Onboarding_Fee__c', 'Deposit_Fee__c',
#        'Activation_Fee_Dollar__c', 'Processing_Fee__c',
#        'Monthly_License_Fee__c', 'Storage_Amount_Cold_CU_FT__c',
#        'Storage_Amount_Dry_CU_FT__c', 'Storage_Amount_Frozen_CU_FT__c',
#        'Monthly_Shelf_Fee_Cold_Storage__c', 'Monthly_Shelf_Fee_Dry_Storage__c',
#        'Monthly_Shelf_Fee_Frozen_Storage__c', 'CurrencyIsoCode',
#        'Access_Date__c', 'Activation_Date__c', 'Last_Activity__c',
#        'Last_Activity_Date__c', 'Is_Churned__c', 'Churn_Type__c',
#        'Primary_Churn_Reason__c', 'Churn_Reason__c', 'Churn_Date__c',
#        'shelf_frozen_fee_usd', 'shelf_dry_fee_usd', 'shelf_cold_fee_usd',
#        'Negotiation_Date__c', 'Qualifying_Date__c', 'Pitching_Date__c',
#        'Commitment_Date__c', 'Hot_Level__c', 'Initial_Discount_Length__c',
#        'CloseDate', 'Amount', 'LastModifiedDate', 'SkuSku_Organization_ID__c',
#        'SkuSku_Facility_ID__c', 'Nurturing_Date__c', 'Loss_Reason__c',
#        'Closed_Lost_Date__c', 'General_Lost_Reason__c', 'Previous_Stage__c',
#        'Move_In_Date__c', 'Completed_in_person_tour__c', 'No_Show2__c',
#        'Access_Date_Checkbox__c', 'Specific_Lost_Reason__c',
#        'Lost_Explanation__c', 'Account_name', 'Account_status', 'Account_ID18',
#        'campaign_name', 'Owner_name', 'sfdc_org_id', 'superset_org_id',
#        'created_by_name', 'created_by_date'],
#       dtype='object')

# %%
opp['MRR_local']=opp['Monthly_Shelf_Fee_Cold_Storage__c']+opp['Monthly_Shelf_Fee_Dry_Storage__c']+opp['Monthly_Shelf_Fee_Frozen_Storage__c']

# %%
from currency_converter import CurrencyConverter

# %%
c = CurrencyConverter()

# %%
opp['Kitchen_Country__c'].value_counts()
# Out:
# United States     9807
# Mexico             104
# Canada               7
# Colombia             6
# Costa Rica           1
# Australia            1
# United Kingdom       1
# Name: Kitchen_Country__c, dtype: int64

# %%
#tipo de cambio
MXN=c.convert(1, 'MXN', 'USD')
COP=0.00026
reais=c.convert(1, 'BRL', 'USD')
chile=0.0012
costa_rica=0.0016
panama=1
peru=0.27

# %%
#mrr_usd=[]
#for i in range(len(opp['MRR_local'])):
    #if opp['Kitchen_Country__c'][i]=='Mexico':
        #j=opp['MRR_local'][i]*MXN
    #elif opp['Kitchen_Country__c'][i]=='Colombia':
        #j=opp['MRR_local'][i]*COP
    #elif opp['Kitchen_Country__c'][i]=='Brazil':
        #j=opp['MRR_local'][i]*reais
    #elif opp['Kitchen_Country__c'][i]=='Chile':
        #j=opp['MRR_local'][i]*chile
    #elif opp['Kitchen_Country__c'][i]=='Costa Rica':
        #j=opp['MRR_local'][i]*costa_rica
    #elif opp['MRR_local'][i]=='Ecuador':
        #j=opp['MRR_local'][i]
    #else:
        #j=0
        
    #mrr_usd.append(round(j,2))

# %%
#opp['MRR_uds']=mrr_usd

# %%
def formato_usd(x):
    try:
        return float(str(x).replace('USD','').strip())
    except:
        return np.nan

# %%
opp['MRR_usd']=opp['shelf_frozen_fee_usd'].apply(formato_usd)+opp['shelf_dry_fee_usd'].apply(formato_usd)+opp['shelf_cold_fee_usd'].apply(formato_usd)

# %%
opp['MRR_usd']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 10188   NaN
# 10189   NaN
# 10190   NaN
# 10191   NaN
# 10192   NaN
# Name: MRR_usd, Length: 10193, dtype: float64

# %%
opp_exp=opp[['Id','Facility_ID__c', 'Campaign_Detail__c',
       'Campaign__c','campaign_name','SDR_Name__c',
          'LeadSource', 'Account_Name_Jira__c',
        'Opp_Owner_Role__c', 'Opp_Owner_Region__c',
       'Opp_Owner_Country__c', 'Scheduled_virtual_tour__c',
       'Completed_virtual_tour__c', 'SQL_Team_Attribution__c', 'SQL_Date__c',
       'Kitchen_Country__c', 'Lead_Created_Date__c',
         'Name','Owner_name',
       'Opportunity_Owner_Name__c', 'Cuisine_Type__c', 'Type', 'StageName',
       'Days_In_Current_Stage__c', 'Facility_Name__c', 'Closed_Won_Date__c',
       'Start_Date__c', 'End_Date__c', 'Renewal_Term_Length_Months__c',
       'Activation_Fee_Dollar__c', 'Onboarding_Fee__c', 'Deposit_Fee__c',
       'Processing_Fee__c', 'Monthly_License_Fee__c',
       'Storage_Amount_Cold_CU_FT__c', 'Storage_Amount_Dry_CU_FT__c',
       'Storage_Amount_Frozen_CU_FT__c', 'Monthly_Shelf_Fee_Cold_Storage__c',
       'Monthly_Shelf_Fee_Dry_Storage__c',
       'Monthly_Shelf_Fee_Frozen_Storage__c', 'CurrencyIsoCode',
       'Access_Date__c', 'Activation_Date__c', 'Last_Activity__c',
       'Last_Activity_Date__c', 'Is_Churned__c', 'Churn_Type__c',
       'Primary_Churn_Reason__c', 'Churn_Reason__c', 'Churn_Date__c', 
          
          'Account_name', 'Account_status',
       'superset_org_id', 'created_by_name','Account_ID18','created_by_date',
           'Scheduled_virtual_tour_Date__c','Created_Date_Weekly_Reports__c' ,
            'MRR_local','shelf_frozen_fee_usd', 'shelf_dry_fee_usd', 'shelf_cold_fee_usd',
            'MRR_usd',
            'Negotiation_Date__c', 'Qualifying_Date__c', 'Pitching_Date__c',
       'Commitment_Date__c', 'Hot_Level__c', 'Initial_Discount_Length__c',
            'CloseDate', 'Amount','LastModifiedDate','Nurturing_Date__c','Loss_Reason__c',
            'Closed_Lost_Date__c', 'General_Lost_Reason__c', 'Previous_Stage__c',
             'Move_In_Date__c', 'Completed_in_person_tour__c',
            'No_Show2__c',
       'Access_Date_Checkbox__c', 'Specific_Lost_Reason__c',
       'Lost_Explanation__c']]

# %%
opp_exp_2=opp_exp.rename(columns={'Id':'opportunity_id'})

# %%
opp_exp_2
# Out:
#            opportunity_id      Facility_ID__c Campaign_Detail__c Campaign__c  \
# 0      0066T00001A4WzzQAF  001f400001IzqxKAAR               None        None
# 1      0066T00001A4aOsQAJ  0015G00001cbBVQQA2               None        None
# 2      0066T00001A4RVKQA3                None               None        None
# 3      0066T00001A4aCmQAJ  001f400001Ha9uKAAR               None        None
# 4      0066T00001A4hSKQAZ  001f400000OM70XAAT               None        None
# ...                   ...                 ...                ...         ...
# 10188  0066T0000185QLlQAM  001f400001Ha9uKAAR               None        None
# 10189  0065G00000YTrWpQAL  001f400000QNEbqAAH               None        None
# 10190  0065G00000YTrWzQAL  001f400001HXpI7AAL               None        None
# 10191  0065G00000j3iGfQAI  0015G00001dp0pwQAA               None        None
# 10192  0065G00000YTrX9QAL  001f400001OdWW5AAN               None        None
#
#       campaign_name         SDR_Name__c                     LeadSource  \
# 0       no_campaign                None            Data Science Scrape
# 1       no_campaign                None               CR - Outbound AE
# 2       no_campaign    Adam Schomberger   CR - Refresh (Re-engagement)
# 3       no_campaign  Christopher Scarpa     CR - Outbound Social Media
# 4       no_campaign                None            Data Science Scrape
# ...             ...                 ...                            ...
# 10188   no_campaign                None               CR - Outbound AE
# 10189   no_campaign                None                           None
# 10190   no_campaign                None                           None
# 10191   no_campaign         Jaden Hills  Outbound: Targeted email/call
# 10192   no_campaign                None                           None
#
#                           Account_Name_Jira__c            Opp_Owner_Role__c  \
# 0                           Guanatos Ice Cream  CR - Account Executive (AE)
# 1      Ice Cream University Desserts - Correct  CR - Account Executive (AE)
# 2                           Cheezcake Boutique         Account Executive CR
# 3                        The Bakehouse Chicago         Account Executive CR
# 4                   Sister My Sister Bake Shop  CR - Account Executive (AE)
# ...                                        ...                          ...
# 10188              Sweet Temptations Bake Shop         Account Executive CR
# 10189                        Bunch of Munchies                         None
# 10190                        Bunch of Munchies                         None
# 10191                           Khea's Cookies         Account Executive CR
# 10192                        Bunch of Munchies  CR - Account Executive (AE)
#
#       Opp_Owner_Region__c      Opp_Owner_Country__c  \
# 0                  US/CAN  United States of America
# 1                  US/CAN  United States of America
# 2                  US/CAN  United States of America
# 3                  US/CAN  United States of America
# 4                  US/CAN  United States of America
# ...                   ...                       ...
# 10188              US/CAN  United States of America
# 10189              US/CAN             United States
# 10190              US/CAN             United States
# 10191              US/CAN             United States
# 10192              US/CAN  United States of America
#
#        Scheduled_virtual_tour__c  Completed_virtual_tour__c  \
# 0                           True                       True
# 1                           True                       True
# 2                          False                      False
# 3                           True                       True
# 4                           True                       True
# ...                          ...                        ...
# 10188                      False                      False
# 10189                      False                      False
# 10190                      False                      False
# 10191                       True                       True
# 10192                      False                      False
#
#       SQL_Team_Attribution__c SQL_Date__c Kitchen_Country__c  \
# 0                        None  2022-12-15      United States
# 1                        None  2022-12-07      United States
# 2                        None        None      United States
# 3                        None  2022-12-07      United States
# 4                        None  2023-01-10      United States
# ...                       ...         ...                ...
# 10188                    None        None      United States
# 10189                    None        None      United States
# 10190                    None        None      United States
# 10191                    None  2021-10-25      United States
# 10192                    None        None      United States
#
#       Lead_Created_Date__c                                               Name  \
# 0               2022-08-09  Guanatos Ice Cream - SF - Lower Mission (Chart...
# 1               2022-12-07  Ice Cream University Desserts - NYC - Brooklyn...
# 2               2022-04-27                               Cheezcake Boutique -
# 3               2022-12-02  The Bakehouse Chicago - CHI - River West (Supe...
# 4               2021-07-14  Sister My Sister Bake Shop - LA - Pico Union (...
# ...                    ...                                                ...
# 10188           2022-05-25  Sweet Temptations Bake Shop - CHI - River West...
# 10189                 None       Bunch of Munchies - NA-US-CA(S)-LA-Hollywood
# 10190                 None       Bunch of Munchies - NA-US-CA(S)-LA-LongBeach
# 10191           2021-10-08         Khea's Cookies - TX - Dallas (Live Oak St)
# 10192                 None         Bunch of Munchies - NA-US-CA(S)-LA-Anaheim
#
#              Owner_name Opportunity_Owner_Name__c  \
# 0          Neil Sampson              Neil Sampson
# 1          Neil Sampson              Neil Sampson
# 2           Alex Milkes               Alex Milkes
# 3           Alex Milkes               Alex Milkes
# 4         Zakary Garcia             Zakary Garcia
# ...                 ...                       ...
# 10188  Michael DeBlasis          Michael DeBlasis
# 10189       Dan Tadesse               Dan Tadesse
# 10190       Dan Tadesse               Dan Tadesse
# 10191      Albert Hayes              Albert Hayes
# 10192     Zakary Garcia             Zakary Garcia
#
#                                        Cuisine_Type__c                 Type  \
# 0      CR - Ice Cream, Popsicle, Cookie Dough & Gelato                 None
# 1      CR - Ice Cream, Popsicle, Cookie Dough & Gelato  US Monthly Contract
# 2                                                 None                 None
# 3                                                 None                 None
# 4                                     CR - Baked Goods                 None
# ...                                                ...                  ...
# 10188                                             None                 None
# 10189                                             None                 None
# 10190                                             None                 None
# 10191                                             None                 None
# 10192                                             None                 None
#
#          StageName  Days_In_Current_Stage__c             Facility_Name__c  \
# 0        Nurturing                     123.0                         None
# 1       Closed Won                     207.0                         None
# 2      Closed Lost                     110.0                         None
# 3      Closed Lost                      68.0                         None
# 4      Closed Lost                     127.0                         None
# ...            ...                       ...                          ...
# 10188  Closed Lost                     361.0  CHI - River West (Superior)
# 10189   Closed Won                       0.0     LA - Hollywood (Western)
# 10190   Closed Won                       0.0      LA - Long Beach (Daisy)
# 10191  Closed Lost                     495.0    TX - Dallas (Live Oak St)
# 10192   Closed Won                       0.0         LA - Anaheim (Lewis)
#
#       Closed_Won_Date__c Start_Date__c End_Date__c  \
# 0                   None          None        None
# 1             2022-12-08    2022-12-07  2023-12-07
# 2                   None          None        None
# 3                   None          None        None
# 4                   None          None        None
# ...                  ...           ...         ...
# 10188               None          None        None
# 10189         2020-12-11    2021-01-01  2021-12-31
# 10190         2020-12-11    2021-01-01  2021-12-31
# 10191               None          None        None
# 10192         2020-12-11    2021-01-01  2021-12-31
#
#        Renewal_Term_Length_Months__c  Activation_Fee_Dollar__c  \
# 0                                NaN                    2500.0
# 1                               12.0                       0.0
# 2                                NaN                       0.0
# 3                                NaN                    2500.0
# 4                                NaN                    2500.0
# ...                              ...                       ...
# 10188                            NaN                    2500.0
# 10189                            NaN                    7500.0
# 10190                            NaN                    2500.0
# 10191                            NaN                       0.0
# 10192                            NaN                    2500.0
#
#        Onboarding_Fee__c  Deposit_Fee__c  Processing_Fee__c  \
# 0                    NaN             NaN                NaN
# 1                  500.0          1200.0               15.0
# 2                    NaN             NaN                NaN
# 3                    NaN             NaN                NaN
# 4                    NaN             NaN                NaN
# ...                  ...             ...                ...
# 10188                NaN             NaN                NaN
# 10189                0.0             0.0               10.0
# 10190              500.0             0.0               10.0
# 10191                NaN             NaN                NaN
# 10192                0.0             0.0               15.0
#
#        Monthly_License_Fee__c  Storage_Amount_Cold_CU_FT__c  \
# 0                         NaN                           NaN
# 1                         NaN                           0.0
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
# ...                       ...                           ...
# 10188                     NaN                           NaN
# 10189                     NaN                           0.0
# 10190                     NaN                           0.0
# 10191                     NaN                           NaN
# 10192                     NaN                           0.0
#
#        Storage_Amount_Dry_CU_FT__c  Storage_Amount_Frozen_CU_FT__c  \
# 0                              NaN                             NaN
# 1                              0.0                            16.0
# 2                              NaN                             NaN
# 3                              NaN                             NaN
# 4                              NaN                             NaN
# ...                            ...                             ...
# 10188                          NaN                             NaN
# 10189                         16.0                             0.0
# 10190                          8.0                             0.0
# 10191                          NaN                             NaN
# 10192                          8.0                             0.0
#
#        Monthly_Shelf_Fee_Cold_Storage__c  Monthly_Shelf_Fee_Dry_Storage__c  \
# 0                                    NaN                               NaN
# 1                                    0.0                               0.0
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
# ...                                  ...                               ...
# 10188                                NaN                               NaN
# 10189                                0.0                             250.0
# 10190                                0.0                             125.0
# 10191                                NaN                               NaN
# 10192                                0.0                             125.0
#
#        Monthly_Shelf_Fee_Frozen_Storage__c CurrencyIsoCode Access_Date__c  \
# 0                                      NaN             USD           None
# 1                                    600.0             USD           None
# 2                                      NaN             USD           None
# 3                                      NaN             USD           None
# 4                                      NaN             USD           None
# ...                                    ...             ...            ...
# 10188                                  NaN             USD           None
# 10189                                  0.0             USD           None
# 10190                                  0.0             USD           None
# 10191                                  NaN             USD           None
# 10192                                  0.0             USD           None
#
#       Activation_Date__c              Last_Activity__c Last_Activity_Date__c  \
# 0                   None  2023-06-27T19:00:00.000+0000            2023-06-27
# 1                   None                          None            2022-12-15
# 2                   None  2023-06-15T19:00:00.000+0000            2023-06-27
# 3                   None  2023-03-23T19:00:00.000+0000            2023-06-21
# 4                   None  2023-02-01T19:00:00.000+0000            2023-02-27
# ...                  ...                           ...                   ...
# 10188               None  2022-07-07T19:00:00.000+0000            2023-06-21
# 10189               None                          None                  None
# 10190               None                          None                  None
# 10191               None  2022-06-20T19:00:00.000+0000            2023-03-03
# 10192               None                          None                  None
#
#        Is_Churned__c                      Churn_Type__c  \
# 0              False                               None
# 1               True                          Transfers
# 2              False                               None
# 3              False                               None
# 4              False                               None
# ...              ...                                ...
# 10188          False                               None
# 10189           True  Early Termination (after move-in)
# 10190           True  Early Termination (after move-in)
# 10191          False                               None
# 10192           True  Early Termination (after move-in)
#
#                   Primary_Churn_Reason__c Churn_Reason__c Churn_Date__c  \
# 0                                    None            None          None
# 1                 CR - Change in Facility            None    2022-12-14
# 2                                    None            None          None
# 3                                    None            None          None
# 4                                    None            None          None
# ...                                   ...             ...           ...
# 10188                                None            None          None
# 10189  CR - Inventory Supply Chain Issues            None    2022-05-23
# 10190  CR - Inventory Supply Chain Issues            None    2022-05-23
# 10191                                None            None          None
# 10192  CR - Inventory Supply Chain Issues            None    2022-05-23
#
#                                   Account_name               Account_status  \
# 0                           Guanatos Ice Cream                    Nurturing
# 1      Ice Cream University Desserts - Correct             Current Customer
# 2                           Cheezcake Boutique                    Nurturing
# 3                        The Bakehouse Chicago                      Working
# 4                   Sister My Sister Bake Shop  Not Interested at this time
# ...                                        ...                          ...
# 10188              Sweet Temptations Bake Shop                      Working
# 10189                        Bunch of Munchies             Current Customer
# 10190                        Bunch of Munchies             Current Customer
# 10191                           Khea's Cookies  Not Interested at this time
# 10192                        Bunch of Munchies             Current Customer
#
#                             superset_org_id   created_by_name  \
# 0                                 no_org_id      Bayne Hagood
# 1      56191d3b-4c83-43a9-88e4-2c6251afb3b7      Neil Sampson
# 2      b096bf2e-7afd-4940-8f70-39c1b1d58bbc  Adam Schomberger
# 3                                 no_org_id      Chris Scarpa
# 4                                 no_org_id   Abdiel Beckford
# ...                                     ...               ...
# 10188                             no_org_id  Michael DeBlasis
# 10189  cfdf1476-d106-4a24-8f27-0bbb2c2a29f4     Paulo Moreira
# 10190  cfdf1476-d106-4a24-8f27-0bbb2c2a29f4     Paulo Moreira
# 10191                             no_org_id       Jaden Hills
# 10192  cfdf1476-d106-4a24-8f27-0bbb2c2a29f4     Paulo Moreira
#
#              Account_ID18 created_by_date Scheduled_virtual_tour_Date__c  \
# 0      0016T00002xIQ5lQAG      2022-09-06                     2022-12-06
# 1      0016T00002xJshdQAC      2021-02-23                     2022-12-07
# 2      0016T00002xICfnQAG      2022-08-08                           None
# 3      0016T00002xIZYvQAO      2021-09-06                           None
# 4      0016T00002xIoDFQA0      2022-09-05                     2022-12-08
# ...                   ...             ...                            ...
# 10188  0016T00002sDVF7QAO      2021-12-29                           None
# 10189  0015G00001a9QruQAE      2020-10-13                           None
# 10190  0015G00001a9QruQAE      2020-10-13                           None
# 10191  0015G00001p0bnTQAQ      2021-07-14                     2021-10-20
# 10192  0015G00001a9QruQAE      2020-10-13                           None
#
#       Created_Date_Weekly_Reports__c  MRR_local shelf_frozen_fee_usd  \
# 0       2022-12-05T22:31:22.000+0000        NaN
# 1       2022-12-06T17:46:21.000+0000      600.0        MXN 13,128.00
# 2       2022-12-04T21:04:21.000+0000        NaN
# 3       2022-12-06T17:12:20.000+0000        NaN
# 4       2022-12-08T01:09:22.000+0000        NaN
# ...                              ...        ...                  ...
# 10188   2022-07-06T02:36:31.000+0000        NaN
# 10189   2021-02-11T22:37:58.000+0000      250.0             MXN 0.00
# 10190   2021-02-11T22:38:01.000+0000      125.0             MXN 0.00
# 10191   2021-10-19T22:32:23.000+0000        NaN
# 10192   2021-02-11T22:38:06.000+0000      125.0             MXN 0.00
#
#       shelf_dry_fee_usd shelf_cold_fee_usd  MRR_usd Negotiation_Date__c  \
# 0                                               NaN                None
# 1              MXN 0.00           MXN 0.00      NaN          2022-12-08
# 2                                               NaN                None
# 3                                               NaN                None
# 4                                               NaN                None
# ...                 ...                ...      ...                 ...
# 10188                                           NaN                None
# 10189      MXN 5,470.00           MXN 0.00      NaN                None
# 10190      MXN 2,735.00           MXN 0.00      NaN                None
# 10191                                           NaN                None
# 10192      MXN 2,735.00           MXN 0.00      NaN                None
#
#       Qualifying_Date__c Pitching_Date__c Commitment_Date__c Hot_Level__c  \
# 0             2022-12-06       2023-02-01               None         None
# 1             2022-12-07       2022-12-08         2022-12-08         None
# 2             2022-12-05             None               None         None
# 3             2022-12-07             None               None         None
# 4             2022-12-08       2023-01-10               None         None
# ...                  ...              ...                ...          ...
# 10188         2022-07-06             None               None         None
# 10189         2021-02-12             None               None         None
# 10190         2021-02-12             None               None         None
# 10191         2021-10-20             None               None         None
# 10192         2021-02-12             None               None         None
#
#        Initial_Discount_Length__c   CloseDate  Amount  \
# 0                             NaN  2023-01-06  5300.0
# 1                             NaN  2022-12-08  7700.0
# 2                             NaN  2023-03-15     NaN
# 3                             NaN  2023-04-26  4100.0
# 4                             NaN  2023-02-26  4700.0
# ...                           ...         ...     ...
# 10188                         NaN  2022-07-07     NaN
# 10189                         NaN  2020-12-11     NaN
# 10190                         NaN  2020-12-11     NaN
# 10191                         NaN  2022-02-23     NaN
# 10192                         NaN  2020-12-11     NaN
#
#                    LastModifiedDate Nurturing_Date__c Loss_Reason__c  \
# 0      2023-06-27T20:55:53.000+0000        2023-03-02           None
# 1      2023-04-18T14:36:46.000+0000              None           None
# 2      2023-06-27T18:03:58.000+0000              None           None
# 3      2023-06-24T13:24:04.000+0000        2022-12-07           None
# 4      2023-05-21T19:18:34.000+0000        2023-01-10           None
# ...                             ...               ...            ...
# 10188  2023-06-14T01:07:45.000+0000              None           None
# 10189  2023-04-03T20:17:26.000+0000              None           None
# 10190  2023-04-03T20:17:27.000+0000              None           None
# 10191  2022-06-22T20:48:56.000+0000              None           None
# 10192  2023-04-03T20:17:26.000+0000              None           None
#
#       Closed_Lost_Date__c General_Lost_Reason__c       Previous_Stage__c  \
# 0                    None                   None                Pitching
# 1                    None         Labor Concerns                Approved
# 2              2023-03-15              Duplicate              Qualifying
# 3              2023-04-26                Pricing               Nurturing
# 4              2023-02-26                Dormant                Approved
# ...                   ...                    ...                     ...
# 10188          2022-07-07                Concept              Qualifying
# 10189                None                   None                    None
# 10190                None                   None                    None
# 10191          2022-02-23      Stuck in Pipeline  Closed - Not Converted
# 10192                None                   None                    None
#
#       Move_In_Date__c  Completed_in_person_tour__c  No_Show2__c  \
# 0                None                        False        False
# 1                None                        False        False
# 2                None                        False        False
# 3                None                        False        False
# 4                None                        False        False
# ...               ...                          ...          ...
# 10188            None                        False         True
# 10189            None                        False        False
# 10190            None                        False        False
# 10191            None                        False        False
# 10192            None                        False        False
#
#        Access_Date_Checkbox__c Specific_Lost_Reason__c  \
# 0                         True                    None
# 1                         True                    None
# 2                         True                    None
# 3                         True                    None
# 4                         True                    None
# ...                        ...                     ...
# 10188                     True                    None
# 10189                     True                    None
# 10190                     True                    None
# 10191                     True                    None
# 10192                     True                    None
#
#                    Lost_Explanation__c
# 0                                 None
# 1                                 None
# 2                              old opp
# 3        couldn't get over the pricing
# 4                             small co
# ...                                ...
# 10188  Doesn't want to work with ofos.
# 10189                             None
# 10190                             None
# 10191                             None
# 10192                             None
#
# [10193 rows x 83 columns]

# %%
opp_exp_2['SQL_Date__c']=pd.to_datetime(opp_exp_2['SQL_Date__c'], errors='coerce')

# %%
opp_exp_2['Lead_Created_Date__c']=pd.to_datetime(opp_exp_2['Lead_Created_Date__c'], errors='coerce')

# %%
opp_exp_2['Start_Date__c']=pd.to_datetime(opp_exp_2['Start_Date__c'], errors='coerce')

# %%
opp_exp_2['End_Date__c']=pd.to_datetime(opp_exp_2['End_Date__c'], errors='coerce')

# %%
opp_exp_2['Access_Date__c']=pd.to_datetime(opp_exp_2['Access_Date__c'], errors='coerce')

# %%
opp_exp_2['Activation_Date__c']=pd.to_datetime(opp_exp_2['Activation_Date__c'], errors='coerce')

# %%
opp_exp_2['Last_Activity__c']=pd.to_datetime(opp_exp_2['Last_Activity__c'], errors='coerce')

# %%
opp_exp_2['Last_Activity_Date__c']=pd.to_datetime(opp_exp_2['Last_Activity_Date__c'], errors='coerce')

# %%
opp_exp_2['created_by_date']=pd.to_datetime(opp_exp_2['created_by_date'], errors='coerce')

# %%
opp_exp_2['Scheduled_virtual_tour_Date__c']=pd.to_datetime(opp_exp_2['Scheduled_virtual_tour_Date__c'], errors='coerce')

# %%
opp_exp_2['Created_Date_Weekly_Reports__c']=pd.to_datetime(opp_exp_2['Created_Date_Weekly_Reports__c'], errors='coerce')

# %%
opp_exp_2['Negotiation_Date__c']=pd.to_datetime(opp_exp_2['Negotiation_Date__c'], errors='coerce')

# %%
opp_exp_2['Qualifying_Date__c']=pd.to_datetime(opp_exp_2['Qualifying_Date__c'], errors='coerce')

# %%
opp_exp_2['Pitching_Date__c']=pd.to_datetime(opp_exp_2['Pitching_Date__c'], errors='coerce')

# %%
opp_exp_2['Commitment_Date__c']=pd.to_datetime(opp_exp_2['Commitment_Date__c'], errors='coerce')

# %%
opp_exp_2['LastModifiedDate']=pd.to_datetime(opp_exp_2['LastModifiedDate'], errors='coerce')

# %%
opp_exp_2['Nurturing_Date__c']=pd.to_datetime(opp_exp_2['Nurturing_Date__c'], errors='coerce')

# %%
opp_exp_2['Move_In_Date__c']= pd.to_datetime(opp_exp_2['Move_In_Date__c'], errors='coerce')

# %%
opp_exp_2['Created_Date_only_date']=pd.to_datetime(opp_exp_2['Created_Date_Weekly_Reports__c'],errors='coerce').dt.date

# %%
## GSheets Oauth
print('Init Auth')
#gc = pygsheets.authorize(service_file='/home/ruben.lopez/creds_spread.json')


# open the spreedsheet
print('Opening Spreadsheet')

#ss = gc.open_by_key('17VX1EwaZRDAdPI2KkWk7jTXHPuA9FjMaUiIn53JxML8')

# select sheet

#ws = ss.worksheet('title','opps')

print('Clearing Range ...')
#ws.clear(start='A', end='BS')
print('Range CLEARED')

print('Pasting Info ...')
#ws.set_dataframe(opp_exp_2, start="A1",copy_head=True, extend=True, nan= '' )
print('UPDATED!!')
# Out:
# Init Auth
# Opening Spreadsheet
# Clearing Range ...
# Range CLEARED
# Pasting Info ...
# UPDATED!!

# %%
## GSheets Oauth
print('Init Auth')
gc = pygsheets.authorize(service_file='/home/ruben.lopez/creds_spread.json')


# open the spreedsheet
print('Opening Spreadsheet')

ss = gc.open_by_key('1SjBzDiaFzEm8Rc2nOBtp-gNvI16qNzyZN1l1l10pUKs')

# select sheet

ws = ss.worksheet('title','opps')

print('Clearing Range ...')
ws.clear(start='A', end='BS')
print('Range CLEARED')

print('Pasting Info ...')
ws.set_dataframe(opp_exp_2, start="A1",copy_head=True, extend=True, nan= '' )
print('UPDATED!!')
# Out:
# Init Auth
# Opening Spreadsheet
# Clearing Range ...
# Range CLEARED
# Pasting Info ...
# UPDATED!!

# %%
opp_exp_2.to_gbq(credentials = credentials ,
              destination_table='latam_cr_growth.opportunity_US',
              progress_bar = True,
              if_exists='replace'
              #if_exists='append'
                        )
# Out:
# 1it [00:04,  4.69s/it]
